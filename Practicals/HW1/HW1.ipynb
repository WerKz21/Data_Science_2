# %% [markdown]
# # HW 1 - DATA SCIENCE 2
# ## Adam Němec, Emma Kovalčíková

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from pathlib import Path

# %%
# set width of Jupyter notebook
from IPython.core.display import HTML
display(HTML("<style>.container { width:70% !important; }</style>"))

# set some visual properties of displaying pandas DataFrame
pd.options.display.max_columns=200
pd.options.display.max_rows=200
# Out:
# <style>.container { width:70% !important; }</style>

# %%
# Load data - set index column, decimal point, separator
data_file = Path("../Data/2024_DS2_HW1_data_train.csv")
data = pd.read_csv(data_file, sep = ',', decimal = '.', index_col = 'Booking_ID')

# print time of data being loaded - use strftime
print(f'Data loaded on:   {datetime.datetime.now().strftime(format="%Y-%m-%d %H:%M:%S")}')
# Out:
# Data loaded on:   2024-04-17 21:50:06

# %%
data.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
#
#             no_of_special_requests  booking_status
# Booking_ID
# INN10204                       1.0             0.0
# INN20020                       NaN             0.0
# INN16435                       1.0             0.0
# INN07143                       2.0             0.0
# INN20511                       NaN             1.0

# %%
# Print some numbers about data sample size
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
print(f'Number of unique indexes:   {data.index.nunique():,}'.replace(',', ' '))
print(f'Number of columns:   {data.shape[1]:,}'.replace(',', ' '))

data.booking_status.value_counts(dropna=False)
# Out:
# Number of rows:   32 647
# Number of unique indexes:   32 647
# Number of columns:   18
# booking_status
# 0.0    21774
# 1.0    10521
# NaN      352
# Name: count, dtype: int64

# %%
# removing NA's from target
data=data.dropna(subset=['booking_status'])
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
data.booking_status.value_counts(dropna=False)
# Out:
# Number of rows:   32 295
# booking_status
# 0.0    21774
# 1.0    10521
# Name: count, dtype: int64

# %%
#name of the target column
col_target = "booking_status"

data['year'] = data['arrival_year'].fillna(0).astype(int).astype(str)
data['month'] = data['arrival_month'].fillna(0).astype(int).astype(str)
#data['date'] = data['arrival_date'].fillna(0).astype(int).astype(str)

# Pad date and month with leading zero if necessary
data['month'] = data['month'].apply(lambda x: x.zfill(2))
#data['date'] = data['date'].apply(lambda x: x.zfill(2))

# Combine 'year' and 'month' columns to form 'date' column
data['arrival'] = data['year'] + data['month'] #+ data['date']

# Replace 'date' values with NaN where 'year' or 'month' were NaN
data.loc[data['year'] == '0', 'arrival'] = float('nan')
data.loc[data['month'] == '00', 'arrival'] = float('nan')
#data.loc[data['date'] == '00', 'arrival'] = float('nan')

data.drop('year', axis=1, inplace=True)
data.drop('month', axis=1, inplace=True)
#data.drop('date', axis=1, inplace=True)

col_date = 'arrival'
#data.head()
#data['arrival']
data.arrival.value_counts(dropna=False)
# Out:
# arrival
# NaN       3779
# 201810    2661
# 201806    2566
# 201809    2336
# 201808    2169
# 201804    2151
# 201805    2071
# 201807    1987
# 201811    1837
# 201803    1829
# 201812    1634
# 201710    1520
# 201802    1346
# 201709    1295
# 201708     799
# 201801     789
# 201712     717
# 201711     512
# 201707     297
# Name: count, dtype: int64

# %%
data['sample'] = 'default'

# Separate NaN rows from the data
nan_indices = data[data[col_date].isna()].index
non_nan_data = data.dropna(subset=[col_date])
#non_nan_data.arrival_date.value_counts(dropna=False)

# Split the non-NaN data
data_train, data_rest = train_test_split(
    non_nan_data, 
    test_size=0.4, 
    random_state=1907, 
    stratify=non_nan_data[[col_date, col_target]]
)
data.loc[data_train.index, 'sample'] = 'train'

data_valid, data_test = train_test_split(
    data_rest, 
    test_size=0.5, 
    random_state=1907, 
    stratify=data_rest[[col_date, col_target]]
)
data.loc[data_test.index, 'sample'] = 'test'
data.loc[data_valid.index, 'sample'] = 'valid'

data_train_nan, data_rest_nan = train_test_split(
    data.loc[nan_indices], test_size=0.4, random_state=1907, stratify=data.loc[nan_indices][[col_target]]
)
data.loc[data_train_nan.index, 'sample'] = 'train'

data_valid_nan, data_test_nan = train_test_split(
    data_rest_nan, test_size=0.5, random_state=1907, stratify=data_rest_nan[[col_target]]
)
data.loc[data_test_nan.index, 'sample'] = 'test'
data.loc[data_valid_nan.index, 'sample'] = 'valid'

train_mask = (data['sample'] == 'train')
valid_mask = (data['sample'] == 'valid')
test_mask = (data['sample'] == 'test')

# %%
print(data[data['sample']=='train'].shape[0]/data.shape[0]) # ratio between train rows and all rows - checks
print(data[data['sample']=='test'].shape[0]/data.shape[0]) # ratio between test rows and all rows - checks
data[data['sample']=='valid'].shape[0]/data.shape[0] # ratio between valid rows and all rows - checks
# Out:
# 0.5999690354544047
# 0.2000309645455953
# 0.2

# %%
mapping = {0.0: 'No', 1.0: 'Yes'}

# Applying mapping and filling NaN with original NaN
data['required_car_parking_space'] = data['required_car_parking_space'].map(mapping)
data['repeated_guest'] = data['repeated_guest'].map(mapping)

print(data.required_car_parking_space.value_counts(dropna=False))
data.repeated_guest.value_counts(dropna=False)
# Out:
# required_car_parking_space
# No     17077
# NaN    14621
# Yes      597
# Name: count, dtype: int64
# repeated_guest
# NaN    24715
# No      7383
# Yes      197
# Name: count, dtype: int64

# %%
cols_pred = list(data.columns[0:17])
cols_pred

# define list of numerical predictors
cols_pred_num = [col for col in cols_pred if data[col].dtype != 'O']
# define list of categorical predictors
cols_pred_cat = [col for col in cols_pred if data[col].dtype == 'O']

# potřeba upravit 0-1čkové?
print('Numerical predictors:')
print('---------------------')
print(data[cols_pred_num].dtypes)
print()
print('Categorical predictors:')
print('-----------------------')
print(data[cols_pred_cat].dtypes)
# Out:
# Numerical predictors:
# ---------------------
# no_of_adults                            float64
# no_of_children                          float64
# no_of_weekend_nights                    float64
# no_of_week_nights                       float64
# lead_time                               float64
# arrival_year                            float64
# arrival_month                           float64
# arrival_date                            float64
# no_of_previous_cancellations            float64
# no_of_previous_bookings_not_canceled    float64
# avg_price_per_room                      float64
# no_of_special_requests                  float64
# dtype: object
#
# Categorical predictors:
# -----------------------
# type_of_meal_plan             object
# required_car_parking_space    object
# room_type_reserved            object
# market_segment_type           object
# repeated_guest                object
# dtype: object

# %%
def mean_target_encoding(dt, predictor, target, alpha = 0.01):
    total_cnt = len(dt)
    total_cr = np.mean(dt[target])
    dt_grp = dt.groupby(predictor).agg(
        categ_cr = (target, 'mean'),
        categ_cnt = (target, len)
    )
    
    dt_grp['categ_freq'] = dt_grp['categ_cnt'] / total_cnt
    dt_grp['categ_encoding'] = (dt_grp['categ_freq'] * dt_grp['categ_cr'] + alpha * total_cr) / (dt_grp['categ_freq'] + alpha)
    
    return dt_grp[['categ_encoding']].to_dict()['categ_encoding']

# %%
total_cr = np.mean(data[train_mask][col_target])

# encode categorical predictors
for pred in tqdm(cols_pred_cat):
    if len(data[pred].unique()) < 0:
        dummies = pd.get_dummies(
            data[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if data[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in data.columns:
                del data[d]
                
        data = data.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = mean_target_encoding(
            dt=data[train_mask], 
            predictor=pred, 
            target=col_target
        )

        additional_values = set(data[data[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_cr

        data['MTE_' + pred] = data[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_required_car_parking_space',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type',
#  'MTE_repeated_guest']

# %%
booster_sklearn = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=1907,
    verbosity=1,
    eval_metric='auc',
    use_label_encoder=False,
    early_stopping_rounds=10,
    max_depth = 8,
    learning_rate = 0.025,
    n_estimators=10000
)

booster_sklearn.fit(
    data[train_mask][cols_pred].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred].values, data[train_mask][col_target].values),
        (data[test_mask][cols_pred].values, data[test_mask][col_target].values),
        (data[valid_mask][cols_pred].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.78449	validation_1-auc:0.78087	validation_2-auc:0.76725
# [1]	validation_0-auc:0.78665	validation_1-auc:0.78244	validation_2-auc:0.76909
# [2]	validation_0-auc:0.78695	validation_1-auc:0.78382	validation_2-auc:0.76902
# [3]	validation_0-auc:0.78752	validation_1-auc:0.78435	validation_2-auc:0.77001
# [4]	validation_0-auc:0.78912	validation_1-auc:0.78503	validation_2-auc:0.77200
# [5]	validation_0-auc:0.78948	validation_1-auc:0.78511	validation_2-auc:0.77183
# [6]	validation_0-auc:0.78976	validation_1-auc:0.78552	validation_2-auc:0.77196
# [7]	validation_0-auc:0.79417	validation_1-auc:0.79007	validation_2-auc:0.77599
# [8]	validation_0-auc:0.79549	validation_1-auc:0.79132	validation_2-auc:0.77768
# [9]	validation_0-auc:0.79622	validation_1-auc:0.79154	validation_2-auc:0.77841
# [10]	validation_0-auc:0.79751	validation_1-auc:0.79265	validation_2-auc:0.77877
# [11]	validation_0-auc:0.79916	validation_1-auc:0.79337	validation_2-auc:0.78068
# [12]	validation_0-auc:0.80083	validation_1-auc:0.79408	validation_2-auc:0.78272
# [13]	validation_0-auc:0.80126	validation_1-auc:0.79508	validation_2-auc:0.78273
# [14]	validation_0-auc:0.80210	validation_1-auc:0.79553	validation_2-auc:0.78294
# [15]	validation_0-auc:0.80211	validation_1-auc:0.79553	validation_2-auc:0.78312
# [16]	validation_0-auc:0.80271	validation_1-auc:0.79606	validation_2-auc:0.78366
# [17]	validation_0-auc:0.80331	validation_1-auc:0.79592	validation_2-auc:0.78408
# [18]	validation_0-auc:0.80397	validation_1-auc:0.79647	validation_2-auc:0.78505
# [19]	validation_0-auc:0.80430	validation_1-auc:0.79678	validation_2-auc:0.78537
# [20]	validation_0-auc:0.80484	validation_1-auc:0.79692	validation_2-auc:0.78575
# [21]	validation_0-auc:0.80613	validation_1-auc:0.79785	validation_2-auc:0.78688
# [22]	validation_0-auc:0.80614	validation_1-auc:0.79785	validation_2-auc:0.78716
# [23]	validation_0-auc:0.80713	validation_1-auc:0.79853	validation_2-auc:0.78733
# [24]	validation_0-auc:0.80724	validation_1-auc:0.79845	validation_2-auc:0.78748
# [25]	validation_0-auc:0.80771	validation_1-auc:0.79882	validation_2-auc:0.78781
# [26]	validation_0-auc:0.80784	validation_1-auc:0.79894	validation_2-auc:0.78778
# [27]	validation_0-auc:0.80819	validation_1-auc:0.79913	validation_2-auc:0.78803
# [28]	validation_0-auc:0.80834	validation_1-auc:0.79917	validation_2-auc:0.78817
# [29]	validation_0-auc:0.80908	validation_1-auc:0.79916	validation_2-auc:0.78873
# [30]	validation_0-auc:0.80955	validation_1-auc:0.79929	validation_2-auc:0.78904
# [31]	validation_0-auc:0.80965	validation_1-auc:0.79938	validation_2-auc:0.78921
# [32]	validation_0-auc:0.81007	validation_1-auc:0.79926	validation_2-auc:0.78943
# [33]	validation_0-auc:0.81015	validation_1-auc:0.79920	validation_2-auc:0.78946
# [34]	validation_0-auc:0.81062	validation_1-auc:0.79917	validation_2-auc:0.79002
# [35]	validation_0-auc:0.81076	validation_1-auc:0.79913	validation_2-auc:0.79003
# [36]	validation_0-auc:0.81103	validation_1-auc:0.79919	validation_2-auc:0.79015
# [37]	validation_0-auc:0.81227	validation_1-auc:0.79994	validation_2-auc:0.79091
# [38]	validation_0-auc:0.81233	validation_1-auc:0.80009	validation_2-auc:0.79099
# [39]	validation_0-auc:0.81277	validation_1-auc:0.80030	validation_2-auc:0.79138
# [40]	validation_0-auc:0.81351	validation_1-auc:0.80086	validation_2-auc:0.79169
# [41]	validation_0-auc:0.81389	validation_1-auc:0.80112	validation_2-auc:0.79197
# [42]	validation_0-auc:0.81474	validation_1-auc:0.80166	validation_2-auc:0.79227
# [43]	validation_0-auc:0.81477	validation_1-auc:0.80169	validation_2-auc:0.79236
# [44]	validation_0-auc:0.81541	validation_1-auc:0.80198	validation_2-auc:0.79274
# [45]	validation_0-auc:0.81611	validation_1-auc:0.80215	validation_2-auc:0.79302
# [46]	validation_0-auc:0.81631	validation_1-auc:0.80248	validation_2-auc:0.79326
# [47]	validation_0-auc:0.81674	validation_1-auc:0.80268	validation_2-auc:0.79342
# [48]	validation_0-auc:0.81726	validation_1-auc:0.80301	validation_2-auc:0.79370
# [49]	validation_0-auc:0.81785	validation_1-auc:0.80317	validation_2-auc:0.79406
# [50]	validation_0-auc:0.81837	validation_1-auc:0.80349	validation_2-auc:0.79429
# [51]	validation_0-auc:0.81948	validation_1-auc:0.80400	validation_2-auc:0.79497
# [52]	validation_0-auc:0.81965	validation_1-auc:0.80426	validation_2-auc:0.79505
# [53]	validation_0-auc:0.81984	validation_1-auc:0.80447	validation_2-auc:0.79522
# [54]	validation_0-auc:0.82073	validation_1-auc:0.80461	validation_2-auc:0.79546
# [55]	validation_0-auc:0.82131	validation_1-auc:0.80480	validation_2-auc:0.79593
# [56]	validation_0-auc:0.82166	validation_1-auc:0.80516	validation_2-auc:0.79636
# [57]	validation_0-auc:0.82264	validation_1-auc:0.80541	validation_2-auc:0.79693
# [58]	validation_0-auc:0.82350	validation_1-auc:0.80589	validation_2-auc:0.79728
# [59]	validation_0-auc:0.82404	validation_1-auc:0.80605	validation_2-auc:0.79764
# [60]	validation_0-auc:0.82473	validation_1-auc:0.80635	validation_2-auc:0.79795
# [61]	validation_0-auc:0.82516	validation_1-auc:0.80665	validation_2-auc:0.79834
# [62]	validation_0-auc:0.82569	validation_1-auc:0.80691	validation_2-auc:0.79865
# [63]	validation_0-auc:0.82630	validation_1-auc:0.80711	validation_2-auc:0.79882
# [64]	validation_0-auc:0.82674	validation_1-auc:0.80725	validation_2-auc:0.79916
# [65]	validation_0-auc:0.82718	validation_1-auc:0.80744	validation_2-auc:0.79928
# [66]	validation_0-auc:0.82761	validation_1-auc:0.80756	validation_2-auc:0.79939
# [67]	validation_0-auc:0.82799	validation_1-auc:0.80764	validation_2-auc:0.79955
# [68]	validation_0-auc:0.82860	validation_1-auc:0.80788	validation_2-auc:0.79987
# [69]	validation_0-auc:0.82934	validation_1-auc:0.80825	validation_2-auc:0.80009
# [70]	validation_0-auc:0.82986	validation_1-auc:0.80822	validation_2-auc:0.80031
# [71]	validation_0-auc:0.83052	validation_1-auc:0.80850	validation_2-auc:0.80048
# [72]	validation_0-auc:0.83074	validation_1-auc:0.80869	validation_2-auc:0.80066
# [73]	validation_0-auc:0.83084	validation_1-auc:0.80873	validation_2-auc:0.80087
# [74]	validation_0-auc:0.83105	validation_1-auc:0.80887	validation_2-auc:0.80105
# [75]	validation_0-auc:0.83123	validation_1-auc:0.80892	validation_2-auc:0.80122
# [76]	validation_0-auc:0.83140	validation_1-auc:0.80904	validation_2-auc:0.80141
# [77]	validation_0-auc:0.83197	validation_1-auc:0.80931	validation_2-auc:0.80170
# [78]	validation_0-auc:0.83229	validation_1-auc:0.80937	validation_2-auc:0.80190
# [79]	validation_0-auc:0.83244	validation_1-auc:0.80952	validation_2-auc:0.80218
# [80]	validation_0-auc:0.83260	validation_1-auc:0.80962	validation_2-auc:0.80240
# [81]	validation_0-auc:0.83319	validation_1-auc:0.80985	validation_2-auc:0.80254
# [82]	validation_0-auc:0.83333	validation_1-auc:0.80991	validation_2-auc:0.80273
# [83]	validation_0-auc:0.83356	validation_1-auc:0.80998	validation_2-auc:0.80286
# [84]	validation_0-auc:0.83377	validation_1-auc:0.81011	validation_2-auc:0.80297
# [85]	validation_0-auc:0.83399	validation_1-auc:0.81009	validation_2-auc:0.80316
# [86]	validation_0-auc:0.83418	validation_1-auc:0.81012	validation_2-auc:0.80327
# [87]	validation_0-auc:0.83444	validation_1-auc:0.81013	validation_2-auc:0.80336
# [88]	validation_0-auc:0.83457	validation_1-auc:0.81010	validation_2-auc:0.80346
# [89]	validation_0-auc:0.83468	validation_1-auc:0.81018	validation_2-auc:0.80363
# [90]	validation_0-auc:0.83487	validation_1-auc:0.81027	validation_2-auc:0.80381
# [91]	validation_0-auc:0.83505	validation_1-auc:0.81035	validation_2-auc:0.80393
# [92]	validation_0-auc:0.83551	validation_1-auc:0.81051	validation_2-auc:0.80419
# [93]	validation_0-auc:0.83573	validation_1-auc:0.81061	validation_2-auc:0.80430
# [94]	validation_0-auc:0.83583	validation_1-auc:0.81071	validation_2-auc:0.80439
# [95]	validation_0-auc:0.83642	validation_1-auc:0.81088	validation_2-auc:0.80468
# [96]	validation_0-auc:0.83666	validation_1-auc:0.81087	validation_2-auc:0.80480
# [97]	validation_0-auc:0.83695	validation_1-auc:0.81094	validation_2-auc:0.80499
# [98]	validation_0-auc:0.83717	validation_1-auc:0.81097	validation_2-auc:0.80525
# [99]	validation_0-auc:0.83732	validation_1-auc:0.81102	validation_2-auc:0.80543
# [100]	validation_0-auc:0.83741	validation_1-auc:0.81116	validation_2-auc:0.80557
# [101]	validation_0-auc:0.83752	validation_1-auc:0.81121	validation_2-auc:0.80566
# [102]	validation_0-auc:0.83762	validation_1-auc:0.81122	validation_2-auc:0.80572
# [103]	validation_0-auc:0.83774	validation_1-auc:0.81135	validation_2-auc:0.80579
# [104]	validation_0-auc:0.83795	validation_1-auc:0.81146	validation_2-auc:0.80590
# [105]	validation_0-auc:0.83824	validation_1-auc:0.81158	validation_2-auc:0.80611
# [106]	validation_0-auc:0.83846	validation_1-auc:0.81167	validation_2-auc:0.80624
# [107]	validation_0-auc:0.83857	validation_1-auc:0.81177	validation_2-auc:0.80637
# [108]	validation_0-auc:0.83877	validation_1-auc:0.81183	validation_2-auc:0.80649
# [109]	validation_0-auc:0.83883	validation_1-auc:0.81193	validation_2-auc:0.80662
# [110]	validation_0-auc:0.83896	validation_1-auc:0.81196	validation_2-auc:0.80666
# [111]	validation_0-auc:0.83949	validation_1-auc:0.81230	validation_2-auc:0.80690
# [112]	validation_0-auc:0.83964	validation_1-auc:0.81236	validation_2-auc:0.80698
# [113]	validation_0-auc:0.83980	validation_1-auc:0.81246	validation_2-auc:0.80715
# [114]	validation_0-auc:0.83984	validation_1-auc:0.81250	validation_2-auc:0.80723
# [115]	validation_0-auc:0.84033	validation_1-auc:0.81270	validation_2-auc:0.80742
# [116]	validation_0-auc:0.84061	validation_1-auc:0.81283	validation_2-auc:0.80771
# [117]	validation_0-auc:0.84060	validation_1-auc:0.81285	validation_2-auc:0.80781
# [118]	validation_0-auc:0.84083	validation_1-auc:0.81289	validation_2-auc:0.80784
# [119]	validation_0-auc:0.84127	validation_1-auc:0.81313	validation_2-auc:0.80807
# [120]	validation_0-auc:0.84129	validation_1-auc:0.81318	validation_2-auc:0.80814
# [121]	validation_0-auc:0.84132	validation_1-auc:0.81325	validation_2-auc:0.80821
# [122]	validation_0-auc:0.84151	validation_1-auc:0.81327	validation_2-auc:0.80831
# [123]	validation_0-auc:0.84154	validation_1-auc:0.81332	validation_2-auc:0.80842
# [124]	validation_0-auc:0.84180	validation_1-auc:0.81336	validation_2-auc:0.80850
# [125]	validation_0-auc:0.84223	validation_1-auc:0.81357	validation_2-auc:0.80871
# [126]	validation_0-auc:0.84247	validation_1-auc:0.81369	validation_2-auc:0.80898
# [127]	validation_0-auc:0.84251	validation_1-auc:0.81377	validation_2-auc:0.80908
# [128]	validation_0-auc:0.84261	validation_1-auc:0.81382	validation_2-auc:0.80918
# [129]	validation_0-auc:0.84282	validation_1-auc:0.81384	validation_2-auc:0.80922
# [130]	validation_0-auc:0.84290	validation_1-auc:0.81391	validation_2-auc:0.80929
# [131]	validation_0-auc:0.84305	validation_1-auc:0.81393	validation_2-auc:0.80937
# [132]	validation_0-auc:0.84310	validation_1-auc:0.81399	validation_2-auc:0.80944
# [133]	validation_0-auc:0.84325	validation_1-auc:0.81411	validation_2-auc:0.80950
# [134]	validation_0-auc:0.84327	validation_1-auc:0.81417	validation_2-auc:0.80959
# [135]	validation_0-auc:0.84339	validation_1-auc:0.81420	validation_2-auc:0.80966
# [136]	validation_0-auc:0.84347	validation_1-auc:0.81415	validation_2-auc:0.80970
# [137]	validation_0-auc:0.84374	validation_1-auc:0.81425	validation_2-auc:0.80987
# [138]	validation_0-auc:0.84377	validation_1-auc:0.81430	validation_2-auc:0.80994
# [139]	validation_0-auc:0.84406	validation_1-auc:0.81436	validation_2-auc:0.81008
# [140]	validation_0-auc:0.84417	validation_1-auc:0.81438	validation_2-auc:0.81016
# [141]	validation_0-auc:0.84428	validation_1-auc:0.81441	validation_2-auc:0.81016
# [142]	validation_0-auc:0.84452	validation_1-auc:0.81452	validation_2-auc:0.81029
# [143]	validation_0-auc:0.84464	validation_1-auc:0.81457	validation_2-auc:0.81041
# [144]	validation_0-auc:0.84503	validation_1-auc:0.81474	validation_2-auc:0.81053
# [145]	validation_0-auc:0.84505	validation_1-auc:0.81478	validation_2-auc:0.81060
# [146]	validation_0-auc:0.84522	validation_1-auc:0.81489	validation_2-auc:0.81073
# [147]	validation_0-auc:0.84526	validation_1-auc:0.81496	validation_2-auc:0.81078
# [148]	validation_0-auc:0.84553	validation_1-auc:0.81496	validation_2-auc:0.81090
# [149]	validation_0-auc:0.84562	validation_1-auc:0.81497	validation_2-auc:0.81093
# [150]	validation_0-auc:0.84572	validation_1-auc:0.81502	validation_2-auc:0.81100
# [151]	validation_0-auc:0.84577	validation_1-auc:0.81501	validation_2-auc:0.81106
# [152]	validation_0-auc:0.84599	validation_1-auc:0.81501	validation_2-auc:0.81115
# [153]	validation_0-auc:0.84603	validation_1-auc:0.81501	validation_2-auc:0.81121
# [154]	validation_0-auc:0.84623	validation_1-auc:0.81503	validation_2-auc:0.81117
# [155]	validation_0-auc:0.84635	validation_1-auc:0.81500	validation_2-auc:0.81123
# [156]	validation_0-auc:0.84636	validation_1-auc:0.81501	validation_2-auc:0.81126
# [157]	validation_0-auc:0.84640	validation_1-auc:0.81501	validation_2-auc:0.81132
# [158]	validation_0-auc:0.84658	validation_1-auc:0.81511	validation_2-auc:0.81139
# [159]	validation_0-auc:0.84668	validation_1-auc:0.81510	validation_2-auc:0.81140
# [160]	validation_0-auc:0.84676	validation_1-auc:0.81518	validation_2-auc:0.81143
# [161]	validation_0-auc:0.84703	validation_1-auc:0.81521	validation_2-auc:0.81148
# [162]	validation_0-auc:0.84734	validation_1-auc:0.81526	validation_2-auc:0.81152
# [163]	validation_0-auc:0.84743	validation_1-auc:0.81535	validation_2-auc:0.81158
# [164]	validation_0-auc:0.84745	validation_1-auc:0.81539	validation_2-auc:0.81162
# [165]	validation_0-auc:0.84769	validation_1-auc:0.81541	validation_2-auc:0.81164
# [166]	validation_0-auc:0.84779	validation_1-auc:0.81545	validation_2-auc:0.81170
# [167]	validation_0-auc:0.84786	validation_1-auc:0.81548	validation_2-auc:0.81167
# [168]	validation_0-auc:0.84809	validation_1-auc:0.81549	validation_2-auc:0.81168
# [169]	validation_0-auc:0.84811	validation_1-auc:0.81550	validation_2-auc:0.81170
# [170]	validation_0-auc:0.84837	validation_1-auc:0.81552	validation_2-auc:0.81175
# [171]	validation_0-auc:0.84838	validation_1-auc:0.81552	validation_2-auc:0.81180
# [172]	validation_0-auc:0.84866	validation_1-auc:0.81561	validation_2-auc:0.81186
# [173]	validation_0-auc:0.84891	validation_1-auc:0.81569	validation_2-auc:0.81189
# [174]	validation_0-auc:0.84906	validation_1-auc:0.81571	validation_2-auc:0.81193
# [175]	validation_0-auc:0.84915	validation_1-auc:0.81574	validation_2-auc:0.81193
# [176]	validation_0-auc:0.84952	validation_1-auc:0.81575	validation_2-auc:0.81193
# [177]	validation_0-auc:0.84953	validation_1-auc:0.81577	validation_2-auc:0.81199
# [178]	validation_0-auc:0.84954	validation_1-auc:0.81579	validation_2-auc:0.81200
# [179]	validation_0-auc:0.84993	validation_1-auc:0.81576	validation_2-auc:0.81209
# [180]	validation_0-auc:0.85012	validation_1-auc:0.81592	validation_2-auc:0.81214
# [181]	validation_0-auc:0.85025	validation_1-auc:0.81588	validation_2-auc:0.81219
# [182]	validation_0-auc:0.85047	validation_1-auc:0.81582	validation_2-auc:0.81225
# [183]	validation_0-auc:0.85071	validation_1-auc:0.81581	validation_2-auc:0.81230
# [184]	validation_0-auc:0.85093	validation_1-auc:0.81585	validation_2-auc:0.81236
# [185]	validation_0-auc:0.85098	validation_1-auc:0.81588	validation_2-auc:0.81241
# [186]	validation_0-auc:0.85100	validation_1-auc:0.81590	validation_2-auc:0.81244
# [187]	validation_0-auc:0.85112	validation_1-auc:0.81597	validation_2-auc:0.81247
# [188]	validation_0-auc:0.85133	validation_1-auc:0.81602	validation_2-auc:0.81254
# [189]	validation_0-auc:0.85141	validation_1-auc:0.81606	validation_2-auc:0.81259
# [190]	validation_0-auc:0.85163	validation_1-auc:0.81611	validation_2-auc:0.81260
# [191]	validation_0-auc:0.85190	validation_1-auc:0.81613	validation_2-auc:0.81258
# [192]	validation_0-auc:0.85206	validation_1-auc:0.81612	validation_2-auc:0.81258
# [193]	validation_0-auc:0.85211	validation_1-auc:0.81611	validation_2-auc:0.81261
# [194]	validation_0-auc:0.85227	validation_1-auc:0.81616	validation_2-auc:0.81268
# [195]	validation_0-auc:0.85235	validation_1-auc:0.81617	validation_2-auc:0.81275
# [196]	validation_0-auc:0.85249	validation_1-auc:0.81624	validation_2-auc:0.81284
# [197]	validation_0-auc:0.85275	validation_1-auc:0.81627	validation_2-auc:0.81287
# [198]	validation_0-auc:0.85276	validation_1-auc:0.81630	validation_2-auc:0.81290
# [199]	validation_0-auc:0.85281	validation_1-auc:0.81630	validation_2-auc:0.81291
# [200]	validation_0-auc:0.85294	validation_1-auc:0.81630	validation_2-auc:0.81292
# [201]	validation_0-auc:0.85298	validation_1-auc:0.81629	validation_2-auc:0.81298
# [202]	validation_0-auc:0.85332	validation_1-auc:0.81631	validation_2-auc:0.81299
# [203]	validation_0-auc:0.85334	validation_1-auc:0.81632	validation_2-auc:0.81303
# [204]	validation_0-auc:0.85348	validation_1-auc:0.81635	validation_2-auc:0.81305
# [205]	validation_0-auc:0.85395	validation_1-auc:0.81651	validation_2-auc:0.81316
# [206]	validation_0-auc:0.85427	validation_1-auc:0.81652	validation_2-auc:0.81319
# [207]	validation_0-auc:0.85440	validation_1-auc:0.81659	validation_2-auc:0.81323
# [208]	validation_0-auc:0.85442	validation_1-auc:0.81660	validation_2-auc:0.81327
# [209]	validation_0-auc:0.85460	validation_1-auc:0.81659	validation_2-auc:0.81329
# [210]	validation_0-auc:0.85508	validation_1-auc:0.81666	validation_2-auc:0.81337
# [211]	validation_0-auc:0.85524	validation_1-auc:0.81663	validation_2-auc:0.81336
# [212]	validation_0-auc:0.85558	validation_1-auc:0.81675	validation_2-auc:0.81343
# [213]	validation_0-auc:0.85566	validation_1-auc:0.81681	validation_2-auc:0.81349
# [214]	validation_0-auc:0.85587	validation_1-auc:0.81683	validation_2-auc:0.81348
# [215]	validation_0-auc:0.85621	validation_1-auc:0.81677	validation_2-auc:0.81357
# [216]	validation_0-auc:0.85622	validation_1-auc:0.81678	validation_2-auc:0.81361
# [217]	validation_0-auc:0.85638	validation_1-auc:0.81675	validation_2-auc:0.81362
# [218]	validation_0-auc:0.85662	validation_1-auc:0.81677	validation_2-auc:0.81365
# [219]	validation_0-auc:0.85669	validation_1-auc:0.81681	validation_2-auc:0.81370
# [220]	validation_0-auc:0.85710	validation_1-auc:0.81697	validation_2-auc:0.81385
# [221]	validation_0-auc:0.85712	validation_1-auc:0.81699	validation_2-auc:0.81389
# [222]	validation_0-auc:0.85757	validation_1-auc:0.81700	validation_2-auc:0.81392
# [223]	validation_0-auc:0.85759	validation_1-auc:0.81702	validation_2-auc:0.81394
# [224]	validation_0-auc:0.85774	validation_1-auc:0.81704	validation_2-auc:0.81395
# [225]	validation_0-auc:0.85778	validation_1-auc:0.81704	validation_2-auc:0.81397
# [226]	validation_0-auc:0.85802	validation_1-auc:0.81708	validation_2-auc:0.81397
# [227]	validation_0-auc:0.85815	validation_1-auc:0.81709	validation_2-auc:0.81399
# [228]	validation_0-auc:0.85816	validation_1-auc:0.81710	validation_2-auc:0.81402
# [229]	validation_0-auc:0.85836	validation_1-auc:0.81715	validation_2-auc:0.81408
# [230]	validation_0-auc:0.85870	validation_1-auc:0.81713	validation_2-auc:0.81413
# [231]	validation_0-auc:0.85885	validation_1-auc:0.81716	validation_2-auc:0.81422
# [232]	validation_0-auc:0.85908	validation_1-auc:0.81717	validation_2-auc:0.81424
# [233]	validation_0-auc:0.85915	validation_1-auc:0.81722	validation_2-auc:0.81430
# [234]	validation_0-auc:0.85940	validation_1-auc:0.81719	validation_2-auc:0.81431
# [235]	validation_0-auc:0.85943	validation_1-auc:0.81722	validation_2-auc:0.81432
# [236]	validation_0-auc:0.85951	validation_1-auc:0.81727	validation_2-auc:0.81431
# [237]	validation_0-auc:0.85961	validation_1-auc:0.81727	validation_2-auc:0.81433
# [238]	validation_0-auc:0.85969	validation_1-auc:0.81726	validation_2-auc:0.81432
# [239]	validation_0-auc:0.85999	validation_1-auc:0.81727	validation_2-auc:0.81426
# [240]	validation_0-auc:0.86003	validation_1-auc:0.81729	validation_2-auc:0.81431
# [241]	validation_0-auc:0.86006	validation_1-auc:0.81732	validation_2-auc:0.81432
# [242]	validation_0-auc:0.86035	validation_1-auc:0.81736	validation_2-auc:0.81436
# [243]	validation_0-auc:0.86064	validation_1-auc:0.81745	validation_2-auc:0.81437
# [244]	validation_0-auc:0.86070	validation_1-auc:0.81745	validation_2-auc:0.81438
# [245]	validation_0-auc:0.86103	validation_1-auc:0.81750	validation_2-auc:0.81447
# [246]	validation_0-auc:0.86116	validation_1-auc:0.81750	validation_2-auc:0.81448
# [247]	validation_0-auc:0.86119	validation_1-auc:0.81751	validation_2-auc:0.81450
# [248]	validation_0-auc:0.86155	validation_1-auc:0.81749	validation_2-auc:0.81453
# [249]	validation_0-auc:0.86174	validation_1-auc:0.81749	validation_2-auc:0.81447
# [250]	validation_0-auc:0.86193	validation_1-auc:0.81748	validation_2-auc:0.81445
# [251]	validation_0-auc:0.86200	validation_1-auc:0.81749	validation_2-auc:0.81444
# [252]	validation_0-auc:0.86210	validation_1-auc:0.81749	validation_2-auc:0.81444
# [253]	validation_0-auc:0.86212	validation_1-auc:0.81749	validation_2-auc:0.81447
# [254]	validation_0-auc:0.86226	validation_1-auc:0.81750	validation_2-auc:0.81451
# [255]	validation_0-auc:0.86227	validation_1-auc:0.81751	validation_2-auc:0.81450
# [256]	validation_0-auc:0.86242	validation_1-auc:0.81759	validation_2-auc:0.81457
# [257]	validation_0-auc:0.86251	validation_1-auc:0.81760	validation_2-auc:0.81462
# [258]	validation_0-auc:0.86258	validation_1-auc:0.81760	validation_2-auc:0.81463
# [259]	validation_0-auc:0.86271	validation_1-auc:0.81760	validation_2-auc:0.81467
# [260]	validation_0-auc:0.86288	validation_1-auc:0.81768	validation_2-auc:0.81471
# [261]	validation_0-auc:0.86294	validation_1-auc:0.81768	validation_2-auc:0.81473
# [262]	validation_0-auc:0.86297	validation_1-auc:0.81767	validation_2-auc:0.81477
# [263]	validation_0-auc:0.86312	validation_1-auc:0.81770	validation_2-auc:0.81478
# [264]	validation_0-auc:0.86328	validation_1-auc:0.81778	validation_2-auc:0.81478
# [265]	validation_0-auc:0.86348	validation_1-auc:0.81779	validation_2-auc:0.81477
# [266]	validation_0-auc:0.86350	validation_1-auc:0.81782	validation_2-auc:0.81478
# [267]	validation_0-auc:0.86351	validation_1-auc:0.81783	validation_2-auc:0.81478
# [268]	validation_0-auc:0.86359	validation_1-auc:0.81781	validation_2-auc:0.81482
# [269]	validation_0-auc:0.86369	validation_1-auc:0.81778	validation_2-auc:0.81484
# [270]	validation_0-auc:0.86392	validation_1-auc:0.81780	validation_2-auc:0.81486
# [271]	validation_0-auc:0.86425	validation_1-auc:0.81792	validation_2-auc:0.81497
# [272]	validation_0-auc:0.86425	validation_1-auc:0.81793	validation_2-auc:0.81502
# [273]	validation_0-auc:0.86444	validation_1-auc:0.81791	validation_2-auc:0.81501
# [274]	validation_0-auc:0.86453	validation_1-auc:0.81794	validation_2-auc:0.81498
# [275]	validation_0-auc:0.86474	validation_1-auc:0.81805	validation_2-auc:0.81503
# [276]	validation_0-auc:0.86478	validation_1-auc:0.81806	validation_2-auc:0.81504
# [277]	validation_0-auc:0.86483	validation_1-auc:0.81806	validation_2-auc:0.81505
# [278]	validation_0-auc:0.86519	validation_1-auc:0.81808	validation_2-auc:0.81500
# [279]	validation_0-auc:0.86525	validation_1-auc:0.81810	validation_2-auc:0.81499
# [280]	validation_0-auc:0.86545	validation_1-auc:0.81810	validation_2-auc:0.81500
# [281]	validation_0-auc:0.86563	validation_1-auc:0.81807	validation_2-auc:0.81498
# [282]	validation_0-auc:0.86606	validation_1-auc:0.81811	validation_2-auc:0.81501
# [283]	validation_0-auc:0.86610	validation_1-auc:0.81810	validation_2-auc:0.81503
# [284]	validation_0-auc:0.86610	validation_1-auc:0.81810	validation_2-auc:0.81504
# [285]	validation_0-auc:0.86617	validation_1-auc:0.81812	validation_2-auc:0.81504
# [286]	validation_0-auc:0.86647	validation_1-auc:0.81812	validation_2-auc:0.81500
# [287]	validation_0-auc:0.86666	validation_1-auc:0.81810	validation_2-auc:0.81504
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.025, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10000, n_jobs=None,
#               num_parallel_tree=None, random_state=1907, ...)

# %%
metric = 'auc'
evals_result = booster_sklearn.evals_result()
fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn.best_score
best_iteration = booster_sklearn.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# plt.savefig('test.svg', format='svg')
# plt.close()

# %%
outcomes = dict(zip(cols_pred,booster_sklearn.feature_importances_)).items()

importance_type = 'total_gain'

predictor_strength = sorted([(k, v) for k,v in outcomes], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = 17
plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:17])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:17])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %% [markdown]
# # SHAP

# %%
import shap
shap.initjs()

explainer = shap.TreeExplainer(booster_sklearn)
shap_values = explainer.shap_values(data[cols_pred])

plt.figure()
shap.summary_plot(shap_values, data[cols_pred], max_display=20, show=True)
plt.show()

shap.force_plot(explainer.expected_value, shap_values[0,:], data[cols_pred].iloc[0,:])

shap.plots._waterfall.waterfall_legacy(
    expected_value=explainer.expected_value, 
    shap_values=shap_values[0, :], 
    feature_names=cols_pred, 
    max_display=20
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# # Top 10 predictors

# %%
cols_pred_top10 = [x for x in cols_pred if (x not in list(dict(sorted([(k, v) for k,v in outcomes], key = lambda x: x[1], reverse = True)[-7:]).keys()))]
cols_pred_top10
# Out:
# ['no_of_adults',
#  'no_of_week_nights',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_required_car_parking_space',
#  'MTE_market_segment_type']

# %%
booster_sklearn_top10 = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=1907,
    verbosity=1,
    eval_metric='auc',
    use_label_encoder=False,
    early_stopping_rounds=20,
    max_depth = 9,
    learning_rate = 0.05,
    n_estimators=10000
)

booster_sklearn_top10.fit(
    data[train_mask][cols_pred_top10].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred_top10].values, data[train_mask][col_target].values),
        (data[test_mask][cols_pred_top10].values, data[test_mask][col_target].values),
        (data[valid_mask][cols_pred_top10].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.79701	validation_1-auc:0.78621	validation_2-auc:0.77440
# [1]	validation_0-auc:0.79929	validation_1-auc:0.78662	validation_2-auc:0.77572
# [2]	validation_0-auc:0.79977	validation_1-auc:0.78790	validation_2-auc:0.77590
# [3]	validation_0-auc:0.79990	validation_1-auc:0.78824	validation_2-auc:0.77738
# [4]	validation_0-auc:0.80092	validation_1-auc:0.78852	validation_2-auc:0.77855
# [5]	validation_0-auc:0.80553	validation_1-auc:0.79251	validation_2-auc:0.78199
# [6]	validation_0-auc:0.80810	validation_1-auc:0.79421	validation_2-auc:0.78329
# [7]	validation_0-auc:0.81054	validation_1-auc:0.79576	validation_2-auc:0.78476
# [8]	validation_0-auc:0.81102	validation_1-auc:0.79625	validation_2-auc:0.78508
# [9]	validation_0-auc:0.81283	validation_1-auc:0.79759	validation_2-auc:0.78664
# [10]	validation_0-auc:0.81275	validation_1-auc:0.79751	validation_2-auc:0.78739
# [11]	validation_0-auc:0.81437	validation_1-auc:0.79846	validation_2-auc:0.78781
# [12]	validation_0-auc:0.81478	validation_1-auc:0.79852	validation_2-auc:0.78803
# [13]	validation_0-auc:0.81642	validation_1-auc:0.79953	validation_2-auc:0.78927
# [14]	validation_0-auc:0.81639	validation_1-auc:0.79987	validation_2-auc:0.78976
# [15]	validation_0-auc:0.81798	validation_1-auc:0.80004	validation_2-auc:0.79011
# [16]	validation_0-auc:0.81847	validation_1-auc:0.80064	validation_2-auc:0.78998
# [17]	validation_0-auc:0.81882	validation_1-auc:0.80083	validation_2-auc:0.79038
# [18]	validation_0-auc:0.81973	validation_1-auc:0.80108	validation_2-auc:0.79093
# [19]	validation_0-auc:0.82086	validation_1-auc:0.80185	validation_2-auc:0.79130
# [20]	validation_0-auc:0.82134	validation_1-auc:0.80254	validation_2-auc:0.79218
# [21]	validation_0-auc:0.82250	validation_1-auc:0.80284	validation_2-auc:0.79317
# [22]	validation_0-auc:0.82277	validation_1-auc:0.80285	validation_2-auc:0.79332
# [23]	validation_0-auc:0.82462	validation_1-auc:0.80406	validation_2-auc:0.79470
# [24]	validation_0-auc:0.82618	validation_1-auc:0.80504	validation_2-auc:0.79550
# [25]	validation_0-auc:0.82746	validation_1-auc:0.80563	validation_2-auc:0.79629
# [26]	validation_0-auc:0.82876	validation_1-auc:0.80618	validation_2-auc:0.79688
# [27]	validation_0-auc:0.82944	validation_1-auc:0.80641	validation_2-auc:0.79720
# [28]	validation_0-auc:0.83037	validation_1-auc:0.80702	validation_2-auc:0.79823
# [29]	validation_0-auc:0.83141	validation_1-auc:0.80777	validation_2-auc:0.79896
# [30]	validation_0-auc:0.83289	validation_1-auc:0.80822	validation_2-auc:0.79974
# [31]	validation_0-auc:0.83487	validation_1-auc:0.80868	validation_2-auc:0.80060
# [32]	validation_0-auc:0.83523	validation_1-auc:0.80901	validation_2-auc:0.80096
# [33]	validation_0-auc:0.83659	validation_1-auc:0.80945	validation_2-auc:0.80177
# [34]	validation_0-auc:0.83736	validation_1-auc:0.80981	validation_2-auc:0.80220
# [35]	validation_0-auc:0.83822	validation_1-auc:0.81031	validation_2-auc:0.80269
# [36]	validation_0-auc:0.83896	validation_1-auc:0.81062	validation_2-auc:0.80298
# [37]	validation_0-auc:0.84039	validation_1-auc:0.81118	validation_2-auc:0.80340
# [38]	validation_0-auc:0.84090	validation_1-auc:0.81127	validation_2-auc:0.80382
# [39]	validation_0-auc:0.84191	validation_1-auc:0.81169	validation_2-auc:0.80412
# [40]	validation_0-auc:0.84212	validation_1-auc:0.81187	validation_2-auc:0.80428
# [41]	validation_0-auc:0.84233	validation_1-auc:0.81202	validation_2-auc:0.80447
# [42]	validation_0-auc:0.84340	validation_1-auc:0.81225	validation_2-auc:0.80455
# [43]	validation_0-auc:0.84367	validation_1-auc:0.81245	validation_2-auc:0.80482
# [44]	validation_0-auc:0.84469	validation_1-auc:0.81271	validation_2-auc:0.80500
# [45]	validation_0-auc:0.84514	validation_1-auc:0.81285	validation_2-auc:0.80506
# [46]	validation_0-auc:0.84547	validation_1-auc:0.81302	validation_2-auc:0.80519
# [47]	validation_0-auc:0.84581	validation_1-auc:0.81317	validation_2-auc:0.80548
# [48]	validation_0-auc:0.84636	validation_1-auc:0.81321	validation_2-auc:0.80572
# [49]	validation_0-auc:0.84668	validation_1-auc:0.81336	validation_2-auc:0.80613
# [50]	validation_0-auc:0.84700	validation_1-auc:0.81364	validation_2-auc:0.80638
# [51]	validation_0-auc:0.84745	validation_1-auc:0.81379	validation_2-auc:0.80645
# [52]	validation_0-auc:0.84774	validation_1-auc:0.81378	validation_2-auc:0.80666
# [53]	validation_0-auc:0.84831	validation_1-auc:0.81394	validation_2-auc:0.80694
# [54]	validation_0-auc:0.84882	validation_1-auc:0.81400	validation_2-auc:0.80695
# [55]	validation_0-auc:0.84905	validation_1-auc:0.81406	validation_2-auc:0.80705
# [56]	validation_0-auc:0.84933	validation_1-auc:0.81418	validation_2-auc:0.80744
# [57]	validation_0-auc:0.84959	validation_1-auc:0.81430	validation_2-auc:0.80763
# [58]	validation_0-auc:0.85025	validation_1-auc:0.81431	validation_2-auc:0.80776
# [59]	validation_0-auc:0.85046	validation_1-auc:0.81445	validation_2-auc:0.80815
# [60]	validation_0-auc:0.85068	validation_1-auc:0.81461	validation_2-auc:0.80831
# [61]	validation_0-auc:0.85129	validation_1-auc:0.81472	validation_2-auc:0.80840
# [62]	validation_0-auc:0.85166	validation_1-auc:0.81491	validation_2-auc:0.80864
# [63]	validation_0-auc:0.85233	validation_1-auc:0.81516	validation_2-auc:0.80885
# [64]	validation_0-auc:0.85280	validation_1-auc:0.81519	validation_2-auc:0.80887
# [65]	validation_0-auc:0.85292	validation_1-auc:0.81539	validation_2-auc:0.80890
# [66]	validation_0-auc:0.85332	validation_1-auc:0.81555	validation_2-auc:0.80897
# [67]	validation_0-auc:0.85336	validation_1-auc:0.81549	validation_2-auc:0.80904
# [68]	validation_0-auc:0.85367	validation_1-auc:0.81555	validation_2-auc:0.80915
# [69]	validation_0-auc:0.85408	validation_1-auc:0.81557	validation_2-auc:0.80939
# [70]	validation_0-auc:0.85431	validation_1-auc:0.81566	validation_2-auc:0.80959
# [71]	validation_0-auc:0.85448	validation_1-auc:0.81575	validation_2-auc:0.80966
# [72]	validation_0-auc:0.85458	validation_1-auc:0.81585	validation_2-auc:0.80978
# [73]	validation_0-auc:0.85512	validation_1-auc:0.81594	validation_2-auc:0.80989
# [74]	validation_0-auc:0.85536	validation_1-auc:0.81616	validation_2-auc:0.81004
# [75]	validation_0-auc:0.85558	validation_1-auc:0.81629	validation_2-auc:0.81009
# [76]	validation_0-auc:0.85585	validation_1-auc:0.81620	validation_2-auc:0.81016
# [77]	validation_0-auc:0.85597	validation_1-auc:0.81627	validation_2-auc:0.81029
# [78]	validation_0-auc:0.85629	validation_1-auc:0.81645	validation_2-auc:0.81042
# [79]	validation_0-auc:0.85647	validation_1-auc:0.81654	validation_2-auc:0.81051
# [80]	validation_0-auc:0.85686	validation_1-auc:0.81663	validation_2-auc:0.81063
# [81]	validation_0-auc:0.85720	validation_1-auc:0.81670	validation_2-auc:0.81077
# [82]	validation_0-auc:0.85843	validation_1-auc:0.81681	validation_2-auc:0.81104
# [83]	validation_0-auc:0.85846	validation_1-auc:0.81680	validation_2-auc:0.81115
# [84]	validation_0-auc:0.85908	validation_1-auc:0.81700	validation_2-auc:0.81113
# [85]	validation_0-auc:0.85943	validation_1-auc:0.81719	validation_2-auc:0.81135
# [86]	validation_0-auc:0.85949	validation_1-auc:0.81720	validation_2-auc:0.81139
# [87]	validation_0-auc:0.85980	validation_1-auc:0.81723	validation_2-auc:0.81145
# [88]	validation_0-auc:0.86002	validation_1-auc:0.81730	validation_2-auc:0.81142
# [89]	validation_0-auc:0.86029	validation_1-auc:0.81736	validation_2-auc:0.81151
# [90]	validation_0-auc:0.86041	validation_1-auc:0.81739	validation_2-auc:0.81159
# [91]	validation_0-auc:0.86061	validation_1-auc:0.81734	validation_2-auc:0.81155
# [92]	validation_0-auc:0.86086	validation_1-auc:0.81741	validation_2-auc:0.81160
# [93]	validation_0-auc:0.86092	validation_1-auc:0.81744	validation_2-auc:0.81168
# [94]	validation_0-auc:0.86164	validation_1-auc:0.81731	validation_2-auc:0.81167
# [95]	validation_0-auc:0.86172	validation_1-auc:0.81731	validation_2-auc:0.81167
# [96]	validation_0-auc:0.86285	validation_1-auc:0.81761	validation_2-auc:0.81191
# [97]	validation_0-auc:0.86289	validation_1-auc:0.81765	validation_2-auc:0.81198
# [98]	validation_0-auc:0.86302	validation_1-auc:0.81772	validation_2-auc:0.81209
# [99]	validation_0-auc:0.86341	validation_1-auc:0.81770	validation_2-auc:0.81214
# [100]	validation_0-auc:0.86358	validation_1-auc:0.81774	validation_2-auc:0.81213
# [101]	validation_0-auc:0.86393	validation_1-auc:0.81784	validation_2-auc:0.81223
# [102]	validation_0-auc:0.86400	validation_1-auc:0.81787	validation_2-auc:0.81231
# [103]	validation_0-auc:0.86455	validation_1-auc:0.81791	validation_2-auc:0.81216
# [104]	validation_0-auc:0.86461	validation_1-auc:0.81793	validation_2-auc:0.81218
# [105]	validation_0-auc:0.86523	validation_1-auc:0.81802	validation_2-auc:0.81238
# [106]	validation_0-auc:0.86523	validation_1-auc:0.81801	validation_2-auc:0.81248
# [107]	validation_0-auc:0.86529	validation_1-auc:0.81807	validation_2-auc:0.81256
# [108]	validation_0-auc:0.86553	validation_1-auc:0.81820	validation_2-auc:0.81261
# [109]	validation_0-auc:0.86561	validation_1-auc:0.81832	validation_2-auc:0.81259
# [110]	validation_0-auc:0.86572	validation_1-auc:0.81832	validation_2-auc:0.81270
# [111]	validation_0-auc:0.86580	validation_1-auc:0.81837	validation_2-auc:0.81275
# [112]	validation_0-auc:0.86584	validation_1-auc:0.81841	validation_2-auc:0.81284
# [113]	validation_0-auc:0.86657	validation_1-auc:0.81850	validation_2-auc:0.81295
# [114]	validation_0-auc:0.86663	validation_1-auc:0.81848	validation_2-auc:0.81302
# [115]	validation_0-auc:0.86680	validation_1-auc:0.81852	validation_2-auc:0.81300
# [116]	validation_0-auc:0.86781	validation_1-auc:0.81881	validation_2-auc:0.81328
# [117]	validation_0-auc:0.86795	validation_1-auc:0.81893	validation_2-auc:0.81338
# [118]	validation_0-auc:0.86796	validation_1-auc:0.81899	validation_2-auc:0.81341
# [119]	validation_0-auc:0.86867	validation_1-auc:0.81916	validation_2-auc:0.81345
# [120]	validation_0-auc:0.86924	validation_1-auc:0.81922	validation_2-auc:0.81356
# [121]	validation_0-auc:0.86988	validation_1-auc:0.81923	validation_2-auc:0.81347
# [122]	validation_0-auc:0.86993	validation_1-auc:0.81925	validation_2-auc:0.81351
# [123]	validation_0-auc:0.87038	validation_1-auc:0.81938	validation_2-auc:0.81358
# [124]	validation_0-auc:0.87037	validation_1-auc:0.81941	validation_2-auc:0.81356
# [125]	validation_0-auc:0.87100	validation_1-auc:0.81966	validation_2-auc:0.81361
# [126]	validation_0-auc:0.87106	validation_1-auc:0.81969	validation_2-auc:0.81366
# [127]	validation_0-auc:0.87142	validation_1-auc:0.81968	validation_2-auc:0.81365
# [128]	validation_0-auc:0.87151	validation_1-auc:0.81972	validation_2-auc:0.81372
# [129]	validation_0-auc:0.87250	validation_1-auc:0.81997	validation_2-auc:0.81381
# [130]	validation_0-auc:0.87287	validation_1-auc:0.82011	validation_2-auc:0.81380
# [131]	validation_0-auc:0.87323	validation_1-auc:0.82009	validation_2-auc:0.81377
# [132]	validation_0-auc:0.87329	validation_1-auc:0.82010	validation_2-auc:0.81378
# [133]	validation_0-auc:0.87328	validation_1-auc:0.82013	validation_2-auc:0.81381
# [134]	validation_0-auc:0.87376	validation_1-auc:0.82037	validation_2-auc:0.81384
# [135]	validation_0-auc:0.87401	validation_1-auc:0.82042	validation_2-auc:0.81383
# [136]	validation_0-auc:0.87404	validation_1-auc:0.82041	validation_2-auc:0.81386
# [137]	validation_0-auc:0.87415	validation_1-auc:0.82040	validation_2-auc:0.81388
# [138]	validation_0-auc:0.87449	validation_1-auc:0.82058	validation_2-auc:0.81389
# [139]	validation_0-auc:0.87487	validation_1-auc:0.82057	validation_2-auc:0.81384
# [140]	validation_0-auc:0.87522	validation_1-auc:0.82057	validation_2-auc:0.81382
# [141]	validation_0-auc:0.87522	validation_1-auc:0.82060	validation_2-auc:0.81383
# [142]	validation_0-auc:0.87524	validation_1-auc:0.82058	validation_2-auc:0.81382
# [143]	validation_0-auc:0.87608	validation_1-auc:0.82076	validation_2-auc:0.81411
# [144]	validation_0-auc:0.87609	validation_1-auc:0.82081	validation_2-auc:0.81414
# [145]	validation_0-auc:0.87649	validation_1-auc:0.82079	validation_2-auc:0.81406
# [146]	validation_0-auc:0.87693	validation_1-auc:0.82087	validation_2-auc:0.81411
# [147]	validation_0-auc:0.87699	validation_1-auc:0.82086	validation_2-auc:0.81411
# [148]	validation_0-auc:0.87797	validation_1-auc:0.82096	validation_2-auc:0.81428
# [149]	validation_0-auc:0.87819	validation_1-auc:0.82090	validation_2-auc:0.81425
# [150]	validation_0-auc:0.87844	validation_1-auc:0.82098	validation_2-auc:0.81428
# [151]	validation_0-auc:0.87882	validation_1-auc:0.82103	validation_2-auc:0.81436
# [152]	validation_0-auc:0.87888	validation_1-auc:0.82104	validation_2-auc:0.81439
# [153]	validation_0-auc:0.87925	validation_1-auc:0.82105	validation_2-auc:0.81443
# [154]	validation_0-auc:0.87955	validation_1-auc:0.82113	validation_2-auc:0.81446
# [155]	validation_0-auc:0.87968	validation_1-auc:0.82120	validation_2-auc:0.81450
# [156]	validation_0-auc:0.87972	validation_1-auc:0.82122	validation_2-auc:0.81453
# [157]	validation_0-auc:0.88003	validation_1-auc:0.82123	validation_2-auc:0.81451
# [158]	validation_0-auc:0.88008	validation_1-auc:0.82127	validation_2-auc:0.81449
# [159]	validation_0-auc:0.88065	validation_1-auc:0.82147	validation_2-auc:0.81465
# [160]	validation_0-auc:0.88112	validation_1-auc:0.82151	validation_2-auc:0.81461
# [161]	validation_0-auc:0.88122	validation_1-auc:0.82155	validation_2-auc:0.81461
# [162]	validation_0-auc:0.88136	validation_1-auc:0.82156	validation_2-auc:0.81466
# [163]	validation_0-auc:0.88165	validation_1-auc:0.82164	validation_2-auc:0.81464
# [164]	validation_0-auc:0.88190	validation_1-auc:0.82161	validation_2-auc:0.81460
# [165]	validation_0-auc:0.88195	validation_1-auc:0.82161	validation_2-auc:0.81461
# [166]	validation_0-auc:0.88225	validation_1-auc:0.82176	validation_2-auc:0.81469
# [167]	validation_0-auc:0.88247	validation_1-auc:0.82176	validation_2-auc:0.81471
# [168]	validation_0-auc:0.88270	validation_1-auc:0.82176	validation_2-auc:0.81468
# [169]	validation_0-auc:0.88291	validation_1-auc:0.82171	validation_2-auc:0.81464
# [170]	validation_0-auc:0.88300	validation_1-auc:0.82173	validation_2-auc:0.81469
# [171]	validation_0-auc:0.88320	validation_1-auc:0.82175	validation_2-auc:0.81466
# [172]	validation_0-auc:0.88359	validation_1-auc:0.82196	validation_2-auc:0.81475
# [173]	validation_0-auc:0.88368	validation_1-auc:0.82197	validation_2-auc:0.81476
# [174]	validation_0-auc:0.88446	validation_1-auc:0.82200	validation_2-auc:0.81473
# [175]	validation_0-auc:0.88453	validation_1-auc:0.82203	validation_2-auc:0.81473
# [176]	validation_0-auc:0.88491	validation_1-auc:0.82214	validation_2-auc:0.81477
# [177]	validation_0-auc:0.88516	validation_1-auc:0.82214	validation_2-auc:0.81475
# [178]	validation_0-auc:0.88521	validation_1-auc:0.82214	validation_2-auc:0.81476
# [179]	validation_0-auc:0.88562	validation_1-auc:0.82218	validation_2-auc:0.81485
# [180]	validation_0-auc:0.88585	validation_1-auc:0.82226	validation_2-auc:0.81481
# [181]	validation_0-auc:0.88626	validation_1-auc:0.82235	validation_2-auc:0.81483
# [182]	validation_0-auc:0.88654	validation_1-auc:0.82235	validation_2-auc:0.81479
# [183]	validation_0-auc:0.88659	validation_1-auc:0.82233	validation_2-auc:0.81477
# [184]	validation_0-auc:0.88685	validation_1-auc:0.82237	validation_2-auc:0.81473
# [185]	validation_0-auc:0.88709	validation_1-auc:0.82231	validation_2-auc:0.81474
# [186]	validation_0-auc:0.88746	validation_1-auc:0.82238	validation_2-auc:0.81472
# [187]	validation_0-auc:0.88762	validation_1-auc:0.82244	validation_2-auc:0.81476
# [188]	validation_0-auc:0.88767	validation_1-auc:0.82247	validation_2-auc:0.81474
# [189]	validation_0-auc:0.88825	validation_1-auc:0.82247	validation_2-auc:0.81475
# [190]	validation_0-auc:0.88872	validation_1-auc:0.82253	validation_2-auc:0.81480
# [191]	validation_0-auc:0.88898	validation_1-auc:0.82248	validation_2-auc:0.81473
# [192]	validation_0-auc:0.88906	validation_1-auc:0.82252	validation_2-auc:0.81471
# [193]	validation_0-auc:0.88927	validation_1-auc:0.82247	validation_2-auc:0.81469
# [194]	validation_0-auc:0.88930	validation_1-auc:0.82248	validation_2-auc:0.81473
# [195]	validation_0-auc:0.88954	validation_1-auc:0.82253	validation_2-auc:0.81467
# [196]	validation_0-auc:0.88974	validation_1-auc:0.82258	validation_2-auc:0.81470
# [197]	validation_0-auc:0.89034	validation_1-auc:0.82273	validation_2-auc:0.81471
# [198]	validation_0-auc:0.89041	validation_1-auc:0.82274	validation_2-auc:0.81473
# [199]	validation_0-auc:0.89057	validation_1-auc:0.82275	validation_2-auc:0.81471
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=20,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10000, n_jobs=None,
#               num_parallel_tree=None, random_state=1907, ...)

# %%
metric = 'auc'
evals_result = booster_sklearn_top10.evals_result()
fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn_top10.best_score
best_iteration = booster_sklearn_top10.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# plt.savefig('test.svg', format='svg')
# plt.close()

# %% [markdown]
# # Kaggle

# %%
# Load data - set index column, decimal point, separator
data_file = Path("../Data/2024_DS2_HW1_data_test.csv")
data_kaggle = pd.read_csv(data_file, sep = ',', decimal = '.', index_col = 'Booking_ID')

# print time of data being loaded - use strftime
print(f'Data loaded on:   {datetime.datetime.now().strftime(format="%Y-%m-%d %H:%M:%S")}')
# Out:
# Data loaded on:   2024-04-17 21:50:19

# %%
data_kaggle
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN04969             2.0             NaN                   1.0
# INN34541             2.0             0.0                   NaN
# INN36109             2.0             NaN                   NaN
# INN01554             2.0             NaN                   0.0
# INN24975             2.0             NaN                   NaN
# ...                  ...             ...                   ...
# INN29523             1.0             NaN                   NaN
# INN25061             2.0             NaN                   1.0
# INN08475             2.0             NaN                   NaN
# INN13558             1.0             NaN                   NaN
# INN00626             2.0             NaN                   0.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN04969                  0.0       Meal Plan 1                         NaN
# INN34541                  2.0       Meal Plan 1                         0.0
# INN36109                  2.0       Meal Plan 1                         0.0
# INN01554                  3.0               NaN                         0.0
# INN24975                  NaN               NaN                         0.0
# ...                       ...               ...                         ...
# INN29523                  2.0       Meal Plan 2                         0.0
# INN25061                  NaN      Not Selected                         0.0
# INN08475                  NaN               NaN                         NaN
# INN13558                  0.0       Meal Plan 1                         NaN
# INN00626                  4.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN04969                  NaN        NaN        2017.0            8.0
# INN34541                  NaN        NaN        2018.0            2.0
# INN36109                  NaN        NaN        2018.0           12.0
# INN01554                  NaN        NaN        2018.0            6.0
# INN24975                  NaN        NaN        2018.0            9.0
# ...                       ...        ...           ...            ...
# INN29523          Room_Type 1       39.0        2017.0            8.0
# INN25061                  NaN        NaN        2018.0            6.0
# INN08475                  NaN      308.0        2018.0           11.0
# INN13558                  NaN        NaN        2018.0            7.0
# INN00626          Room_Type 4        NaN        2017.0           10.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN04969            23.0                 NaN             NaN
# INN34541             NaN             Offline             NaN
# INN36109             NaN                 NaN             NaN
# INN01554            21.0              Online             NaN
# INN24975             NaN                 NaN             NaN
# ...                  ...                 ...             ...
# INN29523             NaN             Offline             NaN
# INN25061             NaN              Online             0.0
# INN08475             NaN              Online             NaN
# INN13558            24.0                 NaN             NaN
# INN00626             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN04969                             0.0
# INN34541                             0.0
# INN36109                             0.0
# INN01554                             0.0
# INN24975                             0.0
# ...                                  ...
# INN29523                             0.0
# INN25061                             0.0
# INN08475                             0.0
# INN13558                             3.0
# INN00626                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN04969                                     NaN                 NaN
# INN34541                                     0.0                 NaN
# INN36109                                     NaN                 NaN
# INN01554                                     0.0                 NaN
# INN24975                                     NaN                 NaN
# ...                                          ...                 ...
# INN29523                                     NaN               87.00
# INN25061                                     NaN                 NaN
# INN08475                                     0.0               78.30
# INN13558                                    39.0                 NaN
# INN00626                                     0.0               87.54
#
#             no_of_special_requests
# Booking_ID
# INN04969                       3.0
# INN34541                       NaN
# INN36109                       NaN
# INN01554                       0.0
# INN24975                       2.0
# ...                            ...
# INN29523                       NaN
# INN25061                       NaN
# INN08475                       NaN
# INN13558                       0.0
# INN00626                       NaN
#
# [3593 rows x 17 columns]

# %%
mapping = {0.0: 'No', 1.0: 'Yes'}
data_kaggle['required_car_parking_space'] = data_kaggle['required_car_parking_space'].map(mapping)
data_kaggle['repeated_guest'] = data_kaggle['repeated_guest'].map(mapping)

# %%
mapping = {'Meal Plan 2': 0.42501087, 'Meal Plan 1': 0.31247541, 'Not Selected': 0.33476213, 'Meal Plan 3': 0.32749285}
data_kaggle['MTE_type_of_meal_plan'] = data_kaggle['type_of_meal_plan'].map(mapping)

# %%
mapping = {'No': 0.33115405, 'Yes': 0.17273773}
data_kaggle['MTE_required_car_parking_space'] = data_kaggle['required_car_parking_space'].map(mapping)

# %%
values = np.array([0.37680524, 0.32462439, 0.32859589, 0.33390951, 0.31724109, 0.31384923, 0.32403984])
labels = np.array(['Room_Type 6', 'Room_Type 1', 'Room_Type 4', 'Room_Type 2', 'Room_Type 5', 'Room_Type 7', 'Room_Type 3'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_room_type_reserved'] = data_kaggle['room_type_reserved'].map(mapping)

# %%
values = np.array([0.36860829, 0.30569387, 0.31800141, 0.19553228, 0.15616035])
labels = np.array(['Online', 'Offline', 'Aviation', 'Complementary', 'Corporate'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_market_segment_type'] = data_kaggle['market_segment_type'].map(mapping)

# %%
values = np.array([0.34633785, 0.21505483])
labels = np.array(['No','Yes'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_repeated_guest'] = data_kaggle['repeated_guest'].map(mapping)

# %%
data_kaggle.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN04969             2.0             NaN                   1.0
# INN34541             2.0             0.0                   NaN
# INN36109             2.0             NaN                   NaN
# INN01554             2.0             NaN                   0.0
# INN24975             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan required_car_parking_space  \
# Booking_ID
# INN04969                  0.0       Meal Plan 1                        NaN
# INN34541                  2.0       Meal Plan 1                         No
# INN36109                  2.0       Meal Plan 1                         No
# INN01554                  3.0               NaN                         No
# INN24975                  NaN               NaN                         No
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN04969                  NaN        NaN        2017.0            8.0
# INN34541                  NaN        NaN        2018.0            2.0
# INN36109                  NaN        NaN        2018.0           12.0
# INN01554                  NaN        NaN        2018.0            6.0
# INN24975                  NaN        NaN        2018.0            9.0
#
#             arrival_date market_segment_type repeated_guest  \
# Booking_ID
# INN04969            23.0                 NaN            NaN
# INN34541             NaN             Offline            NaN
# INN36109             NaN                 NaN            NaN
# INN01554            21.0              Online            NaN
# INN24975             NaN                 NaN            NaN
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN04969                             0.0
# INN34541                             0.0
# INN36109                             0.0
# INN01554                             0.0
# INN24975                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN04969                                     NaN                 NaN
# INN34541                                     0.0                 NaN
# INN36109                                     NaN                 NaN
# INN01554                                     0.0                 NaN
# INN24975                                     NaN                 NaN
#
#             no_of_special_requests  MTE_type_of_meal_plan  \
# Booking_ID
# INN04969                       3.0               0.312475
# INN34541                       NaN               0.312475
# INN36109                       NaN               0.312475
# INN01554                       0.0                    NaN
# INN24975                       2.0                    NaN
#
#             MTE_required_car_parking_space  MTE_room_type_reserved  \
# Booking_ID
# INN04969                               NaN                     NaN
# INN34541                          0.331154                     NaN
# INN36109                          0.331154                     NaN
# INN01554                          0.331154                     NaN
# INN24975                          0.331154                     NaN
#
#             MTE_market_segment_type  MTE_repeated_guest
# Booking_ID
# INN04969                        NaN                 NaN
# INN34541                   0.305694                 NaN
# INN36109                        NaN                 NaN
# INN01554                   0.368608                 NaN
# INN24975                        NaN                 NaN

# %%
predictions_sklearn = booster_sklearn.predict_proba(data_kaggle[cols_pred],iteration_range=(0,booster_sklearn.best_iteration))
print(predictions_sklearn[:, 1])

predictions_sklearn_top10 = booster_sklearn_top10.predict_proba(data_kaggle[cols_pred_top10],iteration_range=(0,booster_sklearn_top10.best_iteration))
print(predictions_sklearn_top10[:, 1])
# Out:
# [0.00843186 0.22701158 0.14916088 ... 0.8916026  0.02302748 0.1994507 ]
# [0.00240823 0.17829354 0.13020682 ... 0.8996077  0.25619656 0.21523754]

# %%
csv_file = 'solution.csv'

pred_data = {
    'Booking_ID': data_kaggle.index,
    'booking_status': predictions_sklearn_top10[:, 1],
}
# Creating a DataFrame
df = pd.DataFrame(pred_data)

# File path to save the CSV
csv_file = 'solution.csv'

# Writing to the CSV file
df.to_csv(csv_file, index=False)

print("CSV file generated successfully.")
# Out:
# CSV file generated successfully.
