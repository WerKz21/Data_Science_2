# %% [markdown]
# # HW 1 - DATA SCIENCE 2
# ## Adam Němec, Emma Kovalčíková

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from pathlib import Path

# %%
# set width of Jupyter notebook
from IPython.core.display import HTML
display(HTML("<style>.container { width:70% !important; }</style>"))

# set some visual properties of displaying pandas DataFrame
pd.options.display.max_columns=200
pd.options.display.max_rows=200
# Out:
# <style>.container { width:70% !important; }</style>

# %%
# Load data - set index column, decimal point, separator
data_file = Path("../Data/2024_DS2_HW1_data_train.csv")
data = pd.read_csv(data_file, sep = ',', decimal = '.', index_col = 'Booking_ID')

# print time of data being loaded - use strftime
print(f'Data loaded on:   {datetime.datetime.now().strftime(format="%Y-%m-%d %H:%M:%S")}')
# Out:
# Data loaded on:   2024-04-19 11:51:18

# %%
data.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
#
#             no_of_special_requests  booking_status
# Booking_ID
# INN10204                       1.0             0.0
# INN20020                       NaN             0.0
# INN16435                       1.0             0.0
# INN07143                       2.0             0.0
# INN20511                       NaN             1.0

# %%
# Print some numbers about data sample size
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
print(f'Number of unique indexes:   {data.index.nunique():,}'.replace(',', ' '))
print(f'Number of columns:   {data.shape[1]:,}'.replace(',', ' '))

data.booking_status.value_counts(dropna=False)
# Out:
# Number of rows:   32 647
# Number of unique indexes:   32 647
# Number of columns:   18
# booking_status
# 0.0    21774
# 1.0    10521
# NaN      352
# Name: count, dtype: int64

# %%
# removing NA's from target
data=data.dropna(subset=['booking_status'])
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
data.booking_status.value_counts(dropna=False)
# Out:
# Number of rows:   32 295
# booking_status
# 0.0    21774
# 1.0    10521
# Name: count, dtype: int64

# %%
#name of the target column
col_target = "booking_status"

data['year'] = data['arrival_year'].fillna(0).astype(int).astype(str)
data['month'] = data['arrival_month'].fillna(0).astype(int).astype(str)
#data['date'] = data['arrival_date'].fillna(0).astype(int).astype(str)

# Pad date and month with leading zero if necessary
data['month'] = data['month'].apply(lambda x: x.zfill(2))
#data['date'] = data['date'].apply(lambda x: x.zfill(2))

# Combine 'year' and 'month' columns to form 'date' column
data['arrival'] = data['year'] + data['month'] #+ data['date']

# Replace 'date' values with NaN where 'year' or 'month' were NaN
data.loc[data['year'] == '0', 'arrival'] = float('nan')
data.loc[data['month'] == '00', 'arrival'] = float('nan')
#data.loc[data['date'] == '00', 'arrival'] = float('nan')

data.drop('year', axis=1, inplace=True)
data.drop('month', axis=1, inplace=True)
#data.drop('date', axis=1, inplace=True)

col_date = 'arrival'
#data.head()
#data['arrival']
data.arrival.value_counts(dropna=False)
# Out:
# arrival
# NaN       3779
# 201810    2661
# 201806    2566
# 201809    2336
# 201808    2169
# 201804    2151
# 201805    2071
# 201807    1987
# 201811    1837
# 201803    1829
# 201812    1634
# 201710    1520
# 201802    1346
# 201709    1295
# 201708     799
# 201801     789
# 201712     717
# 201711     512
# 201707     297
# Name: count, dtype: int64

# %%
data['sample'] = 'default'

# Separate NaN rows from the data
nan_indices = data[data[col_date].isna()].index
non_nan_data = data.dropna(subset=[col_date])
#non_nan_data.arrival_date.value_counts(dropna=False)

# Split the non-NaN data
data_train, data_rest = train_test_split(
    non_nan_data, 
    test_size=0.2, 
    random_state=1907, 
    stratify=non_nan_data[[col_date, col_target]]
)
data.loc[data_train.index, 'sample'] = 'train'

data_valid, data_test = train_test_split(
    data_rest, 
    test_size=0.5, 
    random_state=1907, 
    stratify=data_rest[[col_date, col_target]]
)
data.loc[data_test.index, 'sample'] = 'test'
data.loc[data_valid.index, 'sample'] = 'valid'

data_train_nan, data_rest_nan = train_test_split(
    data.loc[nan_indices], test_size=0.2, random_state=1907, stratify=data.loc[nan_indices][[col_target]]
)
data.loc[data_train_nan.index, 'sample'] = 'train'

data_valid_nan, data_test_nan = train_test_split(
    data_rest_nan, test_size=0.5, random_state=1907, stratify=data_rest_nan[[col_target]]
)
data.loc[data_test_nan.index, 'sample'] = 'test'
data.loc[data_valid_nan.index, 'sample'] = 'valid'

train_mask = (data['sample'] == 'train')
valid_mask = (data['sample'] == 'valid')
test_mask = (data['sample'] == 'test')

# %%
print(data[data['sample']=='train'].shape[0]/data.shape[0]) # ratio between train rows and all rows - checks
print(data[data['sample']=='test'].shape[0]/data.shape[0]) # ratio between test rows and all rows - checks
data[data['sample']=='valid'].shape[0]/data.shape[0] # ratio between valid rows and all rows - checks
# Out:
# 0.7999690354544047
# 0.10001548227279765
# 0.10001548227279765

# %%
mapping = {0.0: 'No', 1.0: 'Yes'}

# Applying mapping and filling NaN with original NaN
data['required_car_parking_space'] = data['required_car_parking_space'].map(mapping)
data['repeated_guest'] = data['repeated_guest'].map(mapping)

print(data.required_car_parking_space.value_counts(dropna=False))
data.repeated_guest.value_counts(dropna=False)
# Out:
# required_car_parking_space
# No     17077
# NaN    14621
# Yes      597
# Name: count, dtype: int64
# repeated_guest
# NaN    24715
# No      7383
# Yes      197
# Name: count, dtype: int64

# %%
cols_pred = list(data.columns[0:17])
cols_pred

# define list of numerical predictors
cols_pred_num = [col for col in cols_pred if data[col].dtype != 'O']
# define list of categorical predictors
cols_pred_cat = [col for col in cols_pred if data[col].dtype == 'O']

# potřeba upravit 0-1čkové?
print('Numerical predictors:')
print('---------------------')
print(data[cols_pred_num].dtypes)
print()
print('Categorical predictors:')
print('-----------------------')
print(data[cols_pred_cat].dtypes)
# Out:
# Numerical predictors:
# ---------------------
# no_of_adults                            float64
# no_of_children                          float64
# no_of_weekend_nights                    float64
# no_of_week_nights                       float64
# lead_time                               float64
# arrival_year                            float64
# arrival_month                           float64
# arrival_date                            float64
# no_of_previous_cancellations            float64
# no_of_previous_bookings_not_canceled    float64
# avg_price_per_room                      float64
# no_of_special_requests                  float64
# dtype: object
#
# Categorical predictors:
# -----------------------
# type_of_meal_plan             object
# required_car_parking_space    object
# room_type_reserved            object
# market_segment_type           object
# repeated_guest                object
# dtype: object

# %%
def mean_target_encoding(dt, predictor, target, alpha = 0.01):
    total_cnt = len(dt)
    total_cr = np.mean(dt[target])
    dt_grp = dt.groupby(predictor).agg(
        categ_cr = (target, 'mean'),
        categ_cnt = (target, len)
    )
    
    dt_grp['categ_freq'] = dt_grp['categ_cnt'] / total_cnt
    dt_grp['categ_encoding'] = (dt_grp['categ_freq'] * dt_grp['categ_cr'] + alpha * total_cr) / (dt_grp['categ_freq'] + alpha)
    
    return dt_grp[['categ_encoding']].to_dict()['categ_encoding']

# %%
total_cr = np.mean(data[train_mask][col_target])

# encode categorical predictors
for pred in tqdm(cols_pred_cat):
    if len(data[pred].unique()) < 0:
        dummies = pd.get_dummies(
            data[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if data[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in data.columns:
                del data[d]
                
        data = data.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = mean_target_encoding(
            dt=data[train_mask], 
            predictor=pred, 
            target=col_target
        )

        additional_values = set(data[data[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_cr

        data['MTE_' + pred] = data[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_required_car_parking_space',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type',
#  'MTE_repeated_guest']

# %%
booster_sklearn = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=1907,
    verbosity=1,
    eval_metric='auc',
    use_label_encoder=False,
    early_stopping_rounds=10,
    max_depth = 9,
    learning_rate = 0.045,
    n_estimators=10000
)

booster_sklearn.fit(
    data[train_mask][cols_pred].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred].values, data[train_mask][col_target].values),
        (data[test_mask][cols_pred].values, data[test_mask][col_target].values),
        (data[valid_mask][cols_pred].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.79582	validation_1-auc:0.78197	validation_2-auc:0.77219
# [1]	validation_0-auc:0.79872	validation_1-auc:0.78380	validation_2-auc:0.77635
# [2]	validation_0-auc:0.79976	validation_1-auc:0.78430	validation_2-auc:0.77739
# [3]	validation_0-auc:0.80096	validation_1-auc:0.78428	validation_2-auc:0.77936
# [4]	validation_0-auc:0.80588	validation_1-auc:0.78704	validation_2-auc:0.78360
# [5]	validation_0-auc:0.80558	validation_1-auc:0.78777	validation_2-auc:0.78337
# [6]	validation_0-auc:0.80783	validation_1-auc:0.78823	validation_2-auc:0.78564
# [7]	validation_0-auc:0.80931	validation_1-auc:0.78896	validation_2-auc:0.78669
# [8]	validation_0-auc:0.80959	validation_1-auc:0.78872	validation_2-auc:0.78682
# [9]	validation_0-auc:0.81089	validation_1-auc:0.79028	validation_2-auc:0.78805
# [10]	validation_0-auc:0.81133	validation_1-auc:0.79092	validation_2-auc:0.78854
# [11]	validation_0-auc:0.81290	validation_1-auc:0.79137	validation_2-auc:0.79061
# [12]	validation_0-auc:0.81309	validation_1-auc:0.79126	validation_2-auc:0.79088
# [13]	validation_0-auc:0.81402	validation_1-auc:0.79181	validation_2-auc:0.79229
# [14]	validation_0-auc:0.81539	validation_1-auc:0.79233	validation_2-auc:0.79382
# [15]	validation_0-auc:0.81580	validation_1-auc:0.79286	validation_2-auc:0.79369
# [16]	validation_0-auc:0.81673	validation_1-auc:0.79313	validation_2-auc:0.79405
# [17]	validation_0-auc:0.81713	validation_1-auc:0.79310	validation_2-auc:0.79437
# [18]	validation_0-auc:0.81784	validation_1-auc:0.79371	validation_2-auc:0.79477
# [19]	validation_0-auc:0.81825	validation_1-auc:0.79398	validation_2-auc:0.79546
# [20]	validation_0-auc:0.81920	validation_1-auc:0.79454	validation_2-auc:0.79548
# [21]	validation_0-auc:0.81959	validation_1-auc:0.79423	validation_2-auc:0.79598
# [22]	validation_0-auc:0.82077	validation_1-auc:0.79483	validation_2-auc:0.79635
# [23]	validation_0-auc:0.82143	validation_1-auc:0.79509	validation_2-auc:0.79635
# [24]	validation_0-auc:0.82206	validation_1-auc:0.79566	validation_2-auc:0.79670
# [25]	validation_0-auc:0.82267	validation_1-auc:0.79617	validation_2-auc:0.79679
# [26]	validation_0-auc:0.82445	validation_1-auc:0.79766	validation_2-auc:0.79757
# [27]	validation_0-auc:0.82585	validation_1-auc:0.79863	validation_2-auc:0.79758
# [28]	validation_0-auc:0.82721	validation_1-auc:0.79916	validation_2-auc:0.79804
# [29]	validation_0-auc:0.82797	validation_1-auc:0.79982	validation_2-auc:0.79860
# [30]	validation_0-auc:0.82912	validation_1-auc:0.80049	validation_2-auc:0.79910
# [31]	validation_0-auc:0.83003	validation_1-auc:0.80115	validation_2-auc:0.79981
# [32]	validation_0-auc:0.83108	validation_1-auc:0.80183	validation_2-auc:0.80051
# [33]	validation_0-auc:0.83202	validation_1-auc:0.80220	validation_2-auc:0.80097
# [34]	validation_0-auc:0.83296	validation_1-auc:0.80311	validation_2-auc:0.80153
# [35]	validation_0-auc:0.83367	validation_1-auc:0.80377	validation_2-auc:0.80196
# [36]	validation_0-auc:0.83482	validation_1-auc:0.80415	validation_2-auc:0.80258
# [37]	validation_0-auc:0.83581	validation_1-auc:0.80451	validation_2-auc:0.80289
# [38]	validation_0-auc:0.83662	validation_1-auc:0.80500	validation_2-auc:0.80306
# [39]	validation_0-auc:0.83729	validation_1-auc:0.80535	validation_2-auc:0.80332
# [40]	validation_0-auc:0.83786	validation_1-auc:0.80571	validation_2-auc:0.80352
# [41]	validation_0-auc:0.83903	validation_1-auc:0.80601	validation_2-auc:0.80400
# [42]	validation_0-auc:0.83958	validation_1-auc:0.80649	validation_2-auc:0.80428
# [43]	validation_0-auc:0.83977	validation_1-auc:0.80695	validation_2-auc:0.80448
# [44]	validation_0-auc:0.84036	validation_1-auc:0.80715	validation_2-auc:0.80461
# [45]	validation_0-auc:0.84055	validation_1-auc:0.80722	validation_2-auc:0.80477
# [46]	validation_0-auc:0.84112	validation_1-auc:0.80723	validation_2-auc:0.80504
# [47]	validation_0-auc:0.84173	validation_1-auc:0.80756	validation_2-auc:0.80528
# [48]	validation_0-auc:0.84225	validation_1-auc:0.80775	validation_2-auc:0.80556
# [49]	validation_0-auc:0.84254	validation_1-auc:0.80799	validation_2-auc:0.80568
# [50]	validation_0-auc:0.84272	validation_1-auc:0.80829	validation_2-auc:0.80580
# [51]	validation_0-auc:0.84321	validation_1-auc:0.80862	validation_2-auc:0.80597
# [52]	validation_0-auc:0.84377	validation_1-auc:0.80863	validation_2-auc:0.80617
# [53]	validation_0-auc:0.84393	validation_1-auc:0.80891	validation_2-auc:0.80629
# [54]	validation_0-auc:0.84451	validation_1-auc:0.80922	validation_2-auc:0.80646
# [55]	validation_0-auc:0.84527	validation_1-auc:0.80972	validation_2-auc:0.80665
# [56]	validation_0-auc:0.84577	validation_1-auc:0.80984	validation_2-auc:0.80668
# [57]	validation_0-auc:0.84589	validation_1-auc:0.81006	validation_2-auc:0.80686
# [58]	validation_0-auc:0.84609	validation_1-auc:0.81032	validation_2-auc:0.80707
# [59]	validation_0-auc:0.84699	validation_1-auc:0.81060	validation_2-auc:0.80763
# [60]	validation_0-auc:0.84725	validation_1-auc:0.81064	validation_2-auc:0.80774
# [61]	validation_0-auc:0.84742	validation_1-auc:0.81070	validation_2-auc:0.80785
# [62]	validation_0-auc:0.84758	validation_1-auc:0.81095	validation_2-auc:0.80795
# [63]	validation_0-auc:0.84804	validation_1-auc:0.81115	validation_2-auc:0.80817
# [64]	validation_0-auc:0.84809	validation_1-auc:0.81128	validation_2-auc:0.80834
# [65]	validation_0-auc:0.84828	validation_1-auc:0.81144	validation_2-auc:0.80866
# [66]	validation_0-auc:0.84848	validation_1-auc:0.81164	validation_2-auc:0.80889
# [67]	validation_0-auc:0.84865	validation_1-auc:0.81162	validation_2-auc:0.80892
# [68]	validation_0-auc:0.84905	validation_1-auc:0.81172	validation_2-auc:0.80898
# [69]	validation_0-auc:0.84916	validation_1-auc:0.81188	validation_2-auc:0.80903
# [70]	validation_0-auc:0.84930	validation_1-auc:0.81194	validation_2-auc:0.80926
# [71]	validation_0-auc:0.85018	validation_1-auc:0.81232	validation_2-auc:0.80956
# [72]	validation_0-auc:0.85040	validation_1-auc:0.81244	validation_2-auc:0.80964
# [73]	validation_0-auc:0.85047	validation_1-auc:0.81252	validation_2-auc:0.80968
# [74]	validation_0-auc:0.85066	validation_1-auc:0.81275	validation_2-auc:0.80978
# [75]	validation_0-auc:0.85094	validation_1-auc:0.81287	validation_2-auc:0.80973
# [76]	validation_0-auc:0.85107	validation_1-auc:0.81314	validation_2-auc:0.80980
# [77]	validation_0-auc:0.85185	validation_1-auc:0.81345	validation_2-auc:0.81009
# [78]	validation_0-auc:0.85192	validation_1-auc:0.81356	validation_2-auc:0.81016
# [79]	validation_0-auc:0.85263	validation_1-auc:0.81368	validation_2-auc:0.81000
# [80]	validation_0-auc:0.85269	validation_1-auc:0.81376	validation_2-auc:0.81007
# [81]	validation_0-auc:0.85300	validation_1-auc:0.81397	validation_2-auc:0.81012
# [82]	validation_0-auc:0.85333	validation_1-auc:0.81404	validation_2-auc:0.81000
# [83]	validation_0-auc:0.85344	validation_1-auc:0.81416	validation_2-auc:0.81004
# [84]	validation_0-auc:0.85349	validation_1-auc:0.81423	validation_2-auc:0.81009
# [85]	validation_0-auc:0.85384	validation_1-auc:0.81433	validation_2-auc:0.81014
# [86]	validation_0-auc:0.85396	validation_1-auc:0.81443	validation_2-auc:0.81013
# [87]	validation_0-auc:0.85424	validation_1-auc:0.81464	validation_2-auc:0.81027
# [88]	validation_0-auc:0.85432	validation_1-auc:0.81467	validation_2-auc:0.81041
# [89]	validation_0-auc:0.85503	validation_1-auc:0.81498	validation_2-auc:0.81064
# [90]	validation_0-auc:0.85521	validation_1-auc:0.81515	validation_2-auc:0.81076
# [91]	validation_0-auc:0.85579	validation_1-auc:0.81549	validation_2-auc:0.81104
# [92]	validation_0-auc:0.85603	validation_1-auc:0.81546	validation_2-auc:0.81102
# [93]	validation_0-auc:0.85607	validation_1-auc:0.81553	validation_2-auc:0.81114
# [94]	validation_0-auc:0.85627	validation_1-auc:0.81564	validation_2-auc:0.81125
# [95]	validation_0-auc:0.85668	validation_1-auc:0.81583	validation_2-auc:0.81145
# [96]	validation_0-auc:0.85687	validation_1-auc:0.81584	validation_2-auc:0.81145
# [97]	validation_0-auc:0.85691	validation_1-auc:0.81591	validation_2-auc:0.81147
# [98]	validation_0-auc:0.85702	validation_1-auc:0.81605	validation_2-auc:0.81155
# [99]	validation_0-auc:0.85763	validation_1-auc:0.81626	validation_2-auc:0.81153
# [100]	validation_0-auc:0.85819	validation_1-auc:0.81635	validation_2-auc:0.81155
# [101]	validation_0-auc:0.85828	validation_1-auc:0.81630	validation_2-auc:0.81164
# [102]	validation_0-auc:0.85915	validation_1-auc:0.81666	validation_2-auc:0.81182
# [103]	validation_0-auc:0.85927	validation_1-auc:0.81674	validation_2-auc:0.81188
# [104]	validation_0-auc:0.85940	validation_1-auc:0.81679	validation_2-auc:0.81199
# [105]	validation_0-auc:0.85984	validation_1-auc:0.81699	validation_2-auc:0.81216
# [106]	validation_0-auc:0.85999	validation_1-auc:0.81705	validation_2-auc:0.81217
# [107]	validation_0-auc:0.86006	validation_1-auc:0.81715	validation_2-auc:0.81224
# [108]	validation_0-auc:0.86019	validation_1-auc:0.81731	validation_2-auc:0.81234
# [109]	validation_0-auc:0.86092	validation_1-auc:0.81742	validation_2-auc:0.81232
# [110]	validation_0-auc:0.86097	validation_1-auc:0.81747	validation_2-auc:0.81235
# [111]	validation_0-auc:0.86145	validation_1-auc:0.81758	validation_2-auc:0.81251
# [112]	validation_0-auc:0.86216	validation_1-auc:0.81799	validation_2-auc:0.81263
# [113]	validation_0-auc:0.86234	validation_1-auc:0.81804	validation_2-auc:0.81266
# [114]	validation_0-auc:0.86246	validation_1-auc:0.81817	validation_2-auc:0.81270
# [115]	validation_0-auc:0.86286	validation_1-auc:0.81838	validation_2-auc:0.81270
# [116]	validation_0-auc:0.86290	validation_1-auc:0.81844	validation_2-auc:0.81277
# [117]	validation_0-auc:0.86314	validation_1-auc:0.81850	validation_2-auc:0.81279
# [118]	validation_0-auc:0.86337	validation_1-auc:0.81856	validation_2-auc:0.81280
# [119]	validation_0-auc:0.86339	validation_1-auc:0.81856	validation_2-auc:0.81286
# [120]	validation_0-auc:0.86376	validation_1-auc:0.81866	validation_2-auc:0.81285
# [121]	validation_0-auc:0.86438	validation_1-auc:0.81877	validation_2-auc:0.81274
# [122]	validation_0-auc:0.86446	validation_1-auc:0.81883	validation_2-auc:0.81282
# [123]	validation_0-auc:0.86519	validation_1-auc:0.81908	validation_2-auc:0.81293
# [124]	validation_0-auc:0.86610	validation_1-auc:0.81912	validation_2-auc:0.81317
# [125]	validation_0-auc:0.86617	validation_1-auc:0.81921	validation_2-auc:0.81327
# [126]	validation_0-auc:0.86662	validation_1-auc:0.81916	validation_2-auc:0.81303
# [127]	validation_0-auc:0.86664	validation_1-auc:0.81927	validation_2-auc:0.81309
# [128]	validation_0-auc:0.86717	validation_1-auc:0.81935	validation_2-auc:0.81308
# [129]	validation_0-auc:0.86733	validation_1-auc:0.81944	validation_2-auc:0.81307
# [130]	validation_0-auc:0.86742	validation_1-auc:0.81951	validation_2-auc:0.81310
# [131]	validation_0-auc:0.86750	validation_1-auc:0.81955	validation_2-auc:0.81316
# [132]	validation_0-auc:0.86770	validation_1-auc:0.81969	validation_2-auc:0.81330
# [133]	validation_0-auc:0.86788	validation_1-auc:0.81963	validation_2-auc:0.81340
# [134]	validation_0-auc:0.86795	validation_1-auc:0.81969	validation_2-auc:0.81345
# [135]	validation_0-auc:0.86806	validation_1-auc:0.81964	validation_2-auc:0.81351
# [136]	validation_0-auc:0.86839	validation_1-auc:0.81977	validation_2-auc:0.81350
# [137]	validation_0-auc:0.86853	validation_1-auc:0.81984	validation_2-auc:0.81352
# [138]	validation_0-auc:0.86856	validation_1-auc:0.81993	validation_2-auc:0.81354
# [139]	validation_0-auc:0.86859	validation_1-auc:0.81994	validation_2-auc:0.81357
# [140]	validation_0-auc:0.86907	validation_1-auc:0.81984	validation_2-auc:0.81357
# [141]	validation_0-auc:0.86952	validation_1-auc:0.81983	validation_2-auc:0.81361
# [142]	validation_0-auc:0.87017	validation_1-auc:0.82013	validation_2-auc:0.81371
# [143]	validation_0-auc:0.87031	validation_1-auc:0.82012	validation_2-auc:0.81379
# [144]	validation_0-auc:0.87035	validation_1-auc:0.82022	validation_2-auc:0.81386
# [145]	validation_0-auc:0.87038	validation_1-auc:0.82025	validation_2-auc:0.81387
# [146]	validation_0-auc:0.87047	validation_1-auc:0.82024	validation_2-auc:0.81389
# [147]	validation_0-auc:0.87052	validation_1-auc:0.82027	validation_2-auc:0.81395
# [148]	validation_0-auc:0.87097	validation_1-auc:0.82036	validation_2-auc:0.81383
# [149]	validation_0-auc:0.87113	validation_1-auc:0.82049	validation_2-auc:0.81398
# [150]	validation_0-auc:0.87155	validation_1-auc:0.82060	validation_2-auc:0.81422
# [151]	validation_0-auc:0.87204	validation_1-auc:0.82048	validation_2-auc:0.81406
# [152]	validation_0-auc:0.87207	validation_1-auc:0.82049	validation_2-auc:0.81410
# [153]	validation_0-auc:0.87234	validation_1-auc:0.82055	validation_2-auc:0.81406
# [154]	validation_0-auc:0.87261	validation_1-auc:0.82068	validation_2-auc:0.81400
# [155]	validation_0-auc:0.87302	validation_1-auc:0.82081	validation_2-auc:0.81399
# [156]	validation_0-auc:0.87340	validation_1-auc:0.82068	validation_2-auc:0.81401
# [157]	validation_0-auc:0.87363	validation_1-auc:0.82093	validation_2-auc:0.81406
# [158]	validation_0-auc:0.87369	validation_1-auc:0.82092	validation_2-auc:0.81398
# [159]	validation_0-auc:0.87390	validation_1-auc:0.82098	validation_2-auc:0.81404
# [160]	validation_0-auc:0.87394	validation_1-auc:0.82102	validation_2-auc:0.81407
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.045, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10000, n_jobs=None,
#               num_parallel_tree=None, random_state=1907, ...)

# %%
metric = 'auc'
evals_result = booster_sklearn.evals_result()
fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn.best_score
best_iteration = booster_sklearn.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# plt.savefig('test.svg', format='svg')
# plt.close()

# %%
outcomes = dict(zip(cols_pred,booster_sklearn.feature_importances_)).items()

importance_type = 'total_gain'

predictor_strength = sorted([(k, v) for k,v in outcomes], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = 17
plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:17])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:17])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %% [markdown]
# # SHAP

# %%
import shap
shap.initjs()

explainer = shap.TreeExplainer(booster_sklearn)
shap_values = explainer.shap_values(data[cols_pred])

plt.figure()
shap.summary_plot(shap_values, data[cols_pred], max_display=20, show=True)
plt.show()

shap.force_plot(explainer.expected_value, shap_values[0,:], data[cols_pred].iloc[0,:])

shap.plots._waterfall.waterfall_legacy(
    expected_value=explainer.expected_value, 
    shap_values=shap_values[0, :], 
    feature_names=cols_pred, 
    max_display=20
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# # Top 10 predictors

# %%
cols_pred_top10 = [x for x in cols_pred if (x not in list(dict(sorted([(k, v) for k,v in outcomes], key = lambda x: x[1], reverse = True)[-7:]).keys()))]

# %%
for i in range(5,13):
    for j in range(4,21):
        booster_sklearn_top10 = xgb.XGBClassifier(
            booster='gbtree',
            objective='binary:logistic',
            random_state=1907,
            verbosity=1,
            eval_metric='auc',
            use_label_encoder=False,
            early_stopping_rounds=20,
            max_depth = i,
            learning_rate = j/200,
            n_estimators=10000
        )
                
        booster_sklearn_top10.fit(
            data[train_mask][cols_pred_top10].values, 
            data[train_mask][col_target].astype(int).values,
            eval_set=[
                (data[train_mask][cols_pred_top10].values, data[train_mask][col_target].values),
                (data[test_mask][cols_pred_top10].values, data[test_mask][col_target].values),
                (data[valid_mask][cols_pred_top10].values, data[valid_mask][col_target].values),
            ],
            verbose=False,
        )
        print(i)
        print(j/200)
        print(booster_sklearn_top10.best_score)
        print("------")
# Out:
# 5
# 0.02
# 0.8121915200496708
# ------
# 5
# 0.025
# 0.8139436425661346
# ------
# 5
# 0.03
# 0.8123646176331064
# ------
# 5
# 0.035
# 0.8140251771961157
# ------
# 5
# 0.04
# 0.8153757307595714
# ------
# 5
# 0.045
# 0.8122861351015739
# ------
# 5
# 0.05
# 0.8127470019672954
# ------
# 5
# 0.055
# 0.8116768054470365
# ------
# 5
# 0.06
# 0.8148433575873424
# ------
# 5
# 0.065
# 0.8158222091611788
# ------
# 5
# 0.07
# 0.8134276199213082
# ------
# 5
# 0.075
# 0.8146063839435205
# ------
# 5
# 0.08
# 0.8140443618149347
# ------
# 5
# 0.085
# 0.8139347042778212
# ------
# 5
# 0.09
# 0.8159190042834021
# ------
# 5
# 0.095
# 0.8140574422368568
# ------
# 5
# 0.1
# 0.8118287563483648
# ------
# 6
# 0.02
# 0.8156979451529188
# ------
# 6
# 0.025
# 0.8156471495144547
# ------
# 6
# 0.03
# 0.815999230871191
# ------
# 6
# 0.035
# 0.8145381477424936
# ------
# 6
# 0.04
# 0.81616840432805
# ------
# 6
# 0.045
# 0.8156037661150798
# ------
# 6
# 0.05
# 0.816236858536109
# ------
# 6
# 0.055
# 0.8153510959649515
# ------
# 6
# 0.06
# 0.8163048767301038
# ------
# 6
# 0.065
# 0.817000537169327
# ------
# 6
# 0.07
# 0.8140356415336533
# ------
# 6
# 0.075
# 0.816112158513785
# ------
# 6
# 0.08
# 0.8160035910118317
# ------
# 6
# 0.085
# 0.8141808342169885
# ------
# 6
# 0.09
# 0.8140576602438888
# ------
# 6
# 0.095
# 0.8146338528295569
# ------
# 6
# 0.1
# 0.8165488265989508
# ------
# 7
# 0.02
# 0.8158910993833017
# ------
# 7
# 0.025
# 0.8149137738586896
# ------
# 7
# 0.03
# 0.8162619293447929
# ------
# 7
# 0.035
# 0.8172355487498605
# ------
# 7
# 0.04
# 0.818584794271124
# ------
# 7
# 0.045
# 0.8174478875990624
# ------
# 7
# 0.05
# 0.818365479196897
# ------
# 7
# 0.055
# 0.8164967229182944
# ------
# 7
# 0.06
# 0.8167408907941734
# ------
# 7
# 0.065
# 0.8172213782927782
# ------
# 7
# 0.07
# 0.8154437489535662
# ------
# 7
# 0.075
# 0.8164219465063065
# ------
# 7
# 0.08
# 0.8174313190646277
# ------
# 7
# 0.085
# 0.816951485587119
# ------
# 7
# 0.09
# 0.8174049402137515
# ------
# 7
# 0.095
# 0.816424998604755
# ------
# 7
# 0.1
# 0.8187949530500056
# ------
# 8
# 0.02
# 0.814396661178703
# ------
# 8
# 0.025
# 0.8179307731750195
# ------
# 8
# 0.03
# 0.8160812015152361
# ------
# 8
# 0.035
# 0.8160585287839045
# ------
# 8
# 0.04
# 0.8158357255971649
# ------
# 8
# 0.045
# 0.81616840432805
# ------
# 8
# 0.05
# 0.8170484987163746
# ------
# 8
# 0.055
# 0.8165013010659672
# ------
# 8
# 0.06
# 0.8176212031895301
# ------
# 8
# 0.065
# 0.8187705362624177
# ------
# 8
# 0.07
# 0.8149970525449269
# ------
# 8
# 0.075
# 0.8159562834858801
# ------
# 8
# 0.08
# 0.8165411963528295
# ------
# 8
# 0.085
# 0.8181973957751981
# ------
# 8
# 0.09
# 0.8177751161541467
# ------
# 8
# 0.095
# 0.8165837077240764
# ------
# 8
# 0.1
# 0.8162597492744726
# ------
# 9
# 0.02
# 0.8165592909364885
# ------
# 9
# 0.025
# 0.816181048735908
# ------
# 9
# 0.03
# 0.8156515096550955
# ------
# 9
# 0.035
# 0.8158594883636566
# ------
# 9
# 0.04
# 0.8158915353973658
# ------
# 9
# 0.045
# 0.8156700402528184
# ------
# 9
# 0.05
# 0.817120441036946
# ------
# 9
# 0.055
# 0.815411265905793
# ------
# 9
# 0.06
# 0.8167077537253041
# ------
# 9
# 0.065
# 0.8177624717462887
# ------
# 9
# 0.07
# 0.8153600342532649
# ------
# 9
# 0.075
# 0.8179780807009711
# ------
# 9
# 0.08
# 0.8173726751730104
# ------
# 9
# 0.085
# 0.817708187995312
# ------
# 9
# 0.09
# 0.8160925378809019
# ------
# 9
# 0.095
# 0.8142366440171894
# ------
# 9
# 0.1
# 0.8167236682386427
# ------
# 10
# 0.02
# 0.8143064062674406
# ------
# 10
# 0.025
# 0.8151782163885478
# ------
# 10
# 0.03
# 0.8149057075985043
# ------
# 10
# 0.035
# 0.814146389105927
# ------
# 10
# 0.04
# 0.8156438794089742
# ------
# 10
# 0.045
# 0.8157142956803215
# ------
# 10
# 0.05
# 0.816436988991517
# ------
# 10
# 0.055
# 0.8166070344765041
# ------
# 10
# 0.06
# 0.8169028700189753
# ------
# 10
# 0.065
# 0.8156959830896305
# ------
# 10
# 0.07
# 0.8136676456635785
# ------
# 10
# 0.075
# 0.8155004307818953
# ------
# 10
# 0.08
# 0.8143022641338319
# ------
# 10
# 0.085
# 0.8140175469499944
# ------
# 10
# 0.09
# 0.8173192634501618
# ------
# 10
# 0.095
# 0.8164075580421922
# ------
# 10
# 0.1
# 0.8154103938776649
# ------
# 11
# 0.02
# 0.8131036614717044
# ------
# 11
# 0.025
# 0.816080765501172
# ------
# 11
# 0.03
# 0.8144703475555307
# ------
# 11
# 0.035
# 0.8148167607294341
# ------
# 11
# 0.04
# 0.8151514015236075
# ------
# 11
# 0.045
# 0.8140489399626074
# ------
# 11
# 0.05
# 0.8148764946562116
# ------
# 11
# 0.055
# 0.8135464337537671
# ------
# 11
# 0.06
# 0.8164590077017524
# ------
# 11
# 0.065
# 0.8135948313148789
# ------
# 11
# 0.07
# 0.8137297776677085
# ------
# 11
# 0.075
# 0.8132854793364215
# ------
# 11
# 0.08
# 0.8156449694441343
# ------
# 11
# 0.085
# 0.8159534493944637
# ------
# 11
# 0.09
# 0.8145571143542806
# ------
# 11
# 0.095
# 0.8142793733954683
# ------
# 11
# 0.1
# 0.8139977083100792
# ------
# 12
# 0.02
# 0.8140548261524724
# ------
# 12
# 0.025
# 0.8154494171363992
# ------
# 12
# 0.03
# 0.8147465624651189
# ------
# 12
# 0.035
# 0.8156231687409309
# ------
# 12
# 0.04
# 0.8150280095434759
# ------
# 12
# 0.045
# 0.8146436631459985
# ------
# 12
# 0.05
# 0.8139946562116308
# ------
# 12
# 0.055
# 0.8121727714449157
# ------
# 12
# 0.06
# 0.8144923662657663
# ------
# 12
# 0.065
# 0.8135677984429066
# ------
# 12
# 0.07
# 0.8140990815799755
# ------
# 12
# 0.075
# 0.8157459066999665
# ------
# 12
# 0.08
# 0.812825484498828
# ------
# 12
# 0.085
# 0.8121483546573278
# ------
# 12
# 0.09
# 0.8140162389078022
# ------
# 12
# 0.095
# 0.8119837593481415
# ------
# 12
# 0.1
# 0.8139560689669606
# ------

# %%
metric = 'auc'
evals_result = booster_sklearn_top10.evals_result()
fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn_top10.best_score
best_iteration = booster_sklearn_top10.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# plt.savefig('test.svg', format='svg')
# plt.close()

# %% [markdown]
# # Kaggle

# %%
# Load data - set index column, decimal point, separator
data_file = Path("../Data/2024_DS2_HW1_data_test.csv")
data_kaggle = pd.read_csv(data_file, sep = ',', decimal = '.', index_col = 'Booking_ID')

# print time of data being loaded - use strftime
print(f'Data loaded on:   {datetime.datetime.now().strftime(format="%Y-%m-%d %H:%M:%S")}')

# %%
data_kaggle

# %%
mapping = {0.0: 'No', 1.0: 'Yes'}
data_kaggle['required_car_parking_space'] = data_kaggle['required_car_parking_space'].map(mapping)
data_kaggle['repeated_guest'] = data_kaggle['repeated_guest'].map(mapping)

# %%
mapping = {'Meal Plan 2': 0.42427875, 'Meal Plan 1': 0.31318309, 'Not Selected': 0.32798397, 'Meal Plan 3': 0.32713655}
data_kaggle['MTE_type_of_meal_plan'] = data_kaggle['type_of_meal_plan'].map(mapping)

# %%
mapping = {'No': 0.33087411, 'Yes': 0.17847759}
data_kaggle['MTE_required_car_parking_space'] = data_kaggle['required_car_parking_space'].map(mapping)

# %%
values = np.array([0.3753117 , 0.3236826 , 0.33434192, 0.33716962, 0.30454475, 0.31249378, 0.32454212])
labels = np.array(['Room_Type 6', 'Room_Type 1', 'Room_Type 4', 'Room_Type 2', 'Room_Type 5', 'Room_Type 7', 'Room_Type 3'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_room_type_reserved'] = data_kaggle['room_type_reserved'].map(mapping)

# %%
values = np.array([0.36570619, 0.30665983, 0.31718622, 0.19558499, 0.15711683])
labels = np.array(['Online', 'Offline', 'Aviation', 'Complementary', 'Corporate'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_market_segment_type'] = data_kaggle['market_segment_type'].map(mapping)

# %%
values = np.array([0.34306786, 0.20499584])
labels = np.array(['No','Yes'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_repeated_guest'] = data_kaggle['repeated_guest'].map(mapping)

# %%
data_kaggle.head()

# %%
#predictions_sklearn = booster_sklearn.predict_proba(data_kaggle[cols_pred],iteration_range=(0,booster_sklearn.best_iteration))
#print(predictions_sklearn[:, 1])

predictions_sklearn_top10 = booster_sklearn_top10.predict_proba(data_kaggle[cols_pred_top10],iteration_range=(0,booster_sklearn_top10.best_iteration))
print(predictions_sklearn_top10[:, 1])

# %%
csv_file = 'solution.csv'

pred_data = {
    'Booking_ID': data_kaggle.index,
    'booking_status': predictions_sklearn_top10[:, 1],
}
# Creating a DataFrame
df = pd.DataFrame(pred_data)

# File path to save the CSV
csv_file = 'solution.csv'

# Writing to the CSV file
df.to_csv(csv_file, index=False)

print("CSV file generated successfully.")
