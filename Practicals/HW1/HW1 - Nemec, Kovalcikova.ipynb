# %% [markdown]
# # HW 1 - DATA SCIENCE 2
# ## Adam Němec, Emma Kovalčíková

# %% [markdown]
# Naším úkolem je **modelovat pravděpodobnost pomocí XGBoostu, že potenciální návštěvník hotelu zruší svou online rezervaci**.
# Nejprve načteme potřebné knihovny a naše data:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb
from pathlib import Path

# %%
data_file = Path("../Data/2024_DS2_HW1_data_train.csv")
data = pd.read_csv(data_file, sep = ',', decimal = '.', index_col = 'Booking_ID')

# %% [markdown]
# ## Explorace a úprava dat

# %% [markdown]
# Provedeme základní exploraci dat:

# %%
data.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
#
#             no_of_special_requests  booking_status
# Booking_ID
# INN10204                       1.0             0.0
# INN20020                       NaN             0.0
# INN16435                       1.0             0.0
# INN07143                       2.0             0.0
# INN20511                       NaN             1.0

# %%
# Základní informace o rozměrech našeho datasetu a targetu
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
print(f'Number of unique indexes:   {data.index.nunique():,}'.replace(',', ' '))
print(f'Number of columns:   {data.shape[1]:,}'.replace(',', ' '))

data.booking_status.value_counts(dropna=False)
# Out:
# Number of rows:   32 647
# Number of unique indexes:   32 647
# Number of columns:   18
# booking_status
# 0.0    21774
# 1.0    10521
# NaN      352
# Name: count, dtype: int64

# %% [markdown]
# Z datasetu vyhodíme všechna pozorování, pro která nemáme k dispozici informaci, zda zrušili svou online rezervaci či nikoliv:

# %%
# odebrání NA's z targetu
data=data.dropna(subset=['booking_status'])
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
data.booking_status.value_counts(dropna=False)
# Out:
# Number of rows:   32 295
# booking_status
# 0.0    21774
# 1.0    10521
# Name: count, dtype: int64

# %% [markdown]
# Upravíme binární proměnné do formátu Yes/No:

# %%
mapping = {0.0: 'No', 1.0: 'Yes'}

data['required_car_parking_space'] = data['required_car_parking_space'].map(mapping)
data['repeated_guest'] = data['repeated_guest'].map(mapping)

print(data.required_car_parking_space.value_counts(dropna=False))
data.repeated_guest.value_counts(dropna=False)
# Out:
# required_car_parking_space
# No     17077
# NaN    14621
# Yes      597
# Name: count, dtype: int64
# repeated_guest
# NaN    24715
# No      7383
# Yes      197
# Name: count, dtype: int64

# %% [markdown]
# ## Stratifikace

# %% [markdown]
# Definujeme a spočteme proměnnou 'arrival' ve tvaru YYYYMM, podle které budeme následně stratifikovat:

# %%
#name of the target column
col_target = "booking_status"

data['year'] = data['arrival_year'].fillna(0).astype(int).astype(str)
data['month'] = data['arrival_month'].fillna(0).astype(int).astype(str)
#data['date'] = data['arrival_date'].fillna(0).astype(int).astype(str)

# Pad date and month with leading zero if necessary
data['month'] = data['month'].apply(lambda x: x.zfill(2))
#data['date'] = data['date'].apply(lambda x: x.zfill(2))

# Combine 'year' and 'month' columns to form 'date' column
data['arrival'] = data['year'] + data['month'] #+ data['date']

# Replace 'date' values with NaN where 'year' or 'month' were NaN
data.loc[data['year'] == '0', 'arrival'] = float('nan')
data.loc[data['month'] == '00', 'arrival'] = float('nan')
#data.loc[data['date'] == '00', 'arrival'] = float('nan')

data.drop('year', axis=1, inplace=True)
data.drop('month', axis=1, inplace=True)
#data.drop('date', axis=1, inplace=True)

col_date = 'arrival'
#data.head()
#data['arrival']
data.arrival.value_counts(dropna=False)
# Out:
# arrival
# NaN       3779
# 201810    2661
# 201806    2566
# 201809    2336
# 201808    2169
# 201804    2151
# 201805    2071
# 201807    1987
# 201811    1837
# 201803    1829
# 201812    1634
# 201710    1520
# 201802    1346
# 201709    1295
# 201708     799
# 201801     789
# 201712     717
# 201711     512
# 201707     297
# Name: count, dtype: int64

# %% [markdown]
# Provedeme stratifikaci. Nejprve stratifikujeme pouze ta pozorování, pro která byl rok a měsíc příjezdu pozorován. Tato pozorování rozdělíme na  na train, test a valid sample základě datumu příjezdu 'arrival' a targetu 'booking_status'. Ostatní pozorování rozdělíme ve stejném poměru podle 'booking_status':

# %%
data['sample'] = 'default'

# Separujeme NA's od zbytku dat
nan_indices = data[data[col_date].isna()].index
non_nan_data = data.dropna(subset=[col_date])
#non_nan_data.arrival_date.value_counts(dropna=False)

# Splitneme non-NA data
data_train, data_rest = train_test_split(
    non_nan_data, 
    test_size=0.4, 
    random_state=1907, 
    stratify=non_nan_data[[col_date, col_target]]
)
data.loc[data_train.index, 'sample'] = 'train'

data_valid, data_test = train_test_split(
    data_rest, 
    test_size=0.5, 
    random_state=1907, 
    stratify=data_rest[[col_date, col_target]]
)
data.loc[data_test.index, 'sample'] = 'test'
data.loc[data_valid.index, 'sample'] = 'valid'

data_train_nan, data_rest_nan = train_test_split(
    data.loc[nan_indices], test_size=0.4, random_state=1907, stratify=data.loc[nan_indices][[col_target]]
)
data.loc[data_train_nan.index, 'sample'] = 'train'

data_valid_nan, data_test_nan = train_test_split(
    data_rest_nan, test_size=0.5, random_state=1907, stratify=data_rest_nan[[col_target]]
)
data.loc[data_test_nan.index, 'sample'] = 'test'
data.loc[data_valid_nan.index, 'sample'] = 'valid'

train_mask = (data['sample'] == 'train')
valid_mask = (data['sample'] == 'valid')
test_mask = (data['sample'] == 'test')

# %% [markdown]
# Nakonec zkontrolujeme, zda jsou skutečně poměry správné:

# %%
print(data[data['sample']=='train'].shape[0]/data.shape[0]) # ratio between train rows and all rows - checks
print(data[data['sample']=='test'].shape[0]/data.shape[0]) # ratio between test rows and all rows - checks
data[data['sample']=='valid'].shape[0]/data.shape[0] # ratio between valid rows and all rows - checks
# Out:
# 0.5999690354544047
# 0.2000309645455953
# 0.2

# %% [markdown]
# ## Zavedení prediktorů a Mean Target Encoding

# %% [markdown]
# Zavedeme si vektor prediktorů a nahlédneme, které prediktory jsou numerické a které kategoriální (potřebné úpravy jsme již provedli výše):

# %%
cols_pred = list(data.columns[0:17])
cols_pred

# define list of numerical predictors
cols_pred_num = [col for col in cols_pred if data[col].dtype != 'O']
# define list of categorical predictors
cols_pred_cat = [col for col in cols_pred if data[col].dtype == 'O']

print('Numerical predictors:')
print('---------------------')
print(data[cols_pred_num].dtypes)
print()
print('Categorical predictors:')
print('-----------------------')
print(data[cols_pred_cat].dtypes)
# Out:
# Numerical predictors:
# ---------------------
# no_of_adults                            float64
# no_of_children                          float64
# no_of_weekend_nights                    float64
# no_of_week_nights                       float64
# lead_time                               float64
# arrival_year                            float64
# arrival_month                           float64
# arrival_date                            float64
# no_of_previous_cancellations            float64
# no_of_previous_bookings_not_canceled    float64
# avg_price_per_room                      float64
# no_of_special_requests                  float64
# dtype: object
#
# Categorical predictors:
# -----------------------
# type_of_meal_plan             object
# required_car_parking_space    object
# room_type_reserved            object
# market_segment_type           object
# repeated_guest                object
# dtype: object

# %% [markdown]
# Definujeme funkci, která provede mean target encoding (cr znamená cancellation rate):

# %%
def mean_target_encoding(dt, predictor, target, alpha = 0.01):
    total_cnt = len(dt)
    total_cr = np.mean(dt[target])
    dt_grp = dt.groupby(predictor).agg(
        categ_cr = (target, 'mean'),
        categ_cnt = (target, len)
    )
    
    dt_grp['categ_freq'] = dt_grp['categ_cnt'] / total_cnt
    dt_grp['categ_encoding'] = (dt_grp['categ_freq'] * dt_grp['categ_cr'] + alpha * total_cr) / (dt_grp['categ_freq'] + alpha)
    
    return dt_grp[['categ_encoding']].to_dict()['categ_encoding']

# %% [markdown]
# Provedeme mean target encoding kategoriálních proměnných. Enkódované proměnné označíme předponou MTE_ a nahradíme jimi jejich neenkódované verze ve vektoru prediktorů:

# %%
total_cr = np.mean(data[train_mask][col_target])

# encode categorical predictors
for pred in tqdm(cols_pred_cat):
    if len(data[pred].unique()) < 0:
        dummies = pd.get_dummies(
            data[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if data[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in data.columns:
                del data[d]
                
        data = data.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = mean_target_encoding(
            dt=data[train_mask], 
            predictor=pred, 
            target=col_target
        )

        additional_values = set(data[data[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_cr

        data['MTE_' + pred] = data[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# Náš vektor prediktorů nakonec vypadá takto:

# %%
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_required_car_parking_space',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type',
#  'MTE_repeated_guest']

# %% [markdown]
# ## XGBoost - první model

# %% [markdown]
# Modelujeme probability of cancellation pomocí XGBClassifieru, přičemž k tomu využíváme zatím kompletní vektor prediktorů. Hyperparametry jsou pro porovnání nastaveny tak jako u námi nalezeného nejlepšího modelu, viz níže:

# %%
booster_sklearn = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=1907,
    verbosity=1,
    eval_metric='auc',
    use_label_encoder=False,
    early_stopping_rounds=10,
    max_depth = 9,
    learning_rate = 0.045,
    n_estimators=10000
)

booster_sklearn.fit(
    data[train_mask][cols_pred].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred].values, data[train_mask][col_target].values),
        (data[test_mask][cols_pred].values, data[test_mask][col_target].values),
        (data[valid_mask][cols_pred].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.79758	validation_1-auc:0.78353	validation_2-auc:0.77205
# [1]	validation_0-auc:0.79951	validation_1-auc:0.78677	validation_2-auc:0.77442
# [2]	validation_0-auc:0.80040	validation_1-auc:0.78740	validation_2-auc:0.77525
# [3]	validation_0-auc:0.80085	validation_1-auc:0.78767	validation_2-auc:0.77593
# [4]	validation_0-auc:0.80238	validation_1-auc:0.78866	validation_2-auc:0.77710
# [5]	validation_0-auc:0.80298	validation_1-auc:0.78851	validation_2-auc:0.77811
# [6]	validation_0-auc:0.80790	validation_1-auc:0.79232	validation_2-auc:0.78097
# [7]	validation_0-auc:0.81042	validation_1-auc:0.79414	validation_2-auc:0.78313
# [8]	validation_0-auc:0.81275	validation_1-auc:0.79472	validation_2-auc:0.78452
# [9]	validation_0-auc:0.81437	validation_1-auc:0.79612	validation_2-auc:0.78614
# [10]	validation_0-auc:0.81463	validation_1-auc:0.79624	validation_2-auc:0.78691
# [11]	validation_0-auc:0.81477	validation_1-auc:0.79617	validation_2-auc:0.78688
# [12]	validation_0-auc:0.81628	validation_1-auc:0.79721	validation_2-auc:0.78772
# [13]	validation_0-auc:0.81730	validation_1-auc:0.79766	validation_2-auc:0.78830
# [14]	validation_0-auc:0.81879	validation_1-auc:0.79805	validation_2-auc:0.78903
# [15]	validation_0-auc:0.81942	validation_1-auc:0.79839	validation_2-auc:0.78911
# [16]	validation_0-auc:0.81998	validation_1-auc:0.79879	validation_2-auc:0.78961
# [17]	validation_0-auc:0.82098	validation_1-auc:0.79952	validation_2-auc:0.79010
# [18]	validation_0-auc:0.82126	validation_1-auc:0.79993	validation_2-auc:0.79087
# [19]	validation_0-auc:0.82216	validation_1-auc:0.80028	validation_2-auc:0.79109
# [20]	validation_0-auc:0.82263	validation_1-auc:0.80071	validation_2-auc:0.79116
# [21]	validation_0-auc:0.82289	validation_1-auc:0.80100	validation_2-auc:0.79150
# [22]	validation_0-auc:0.82425	validation_1-auc:0.80108	validation_2-auc:0.79219
# [23]	validation_0-auc:0.82439	validation_1-auc:0.80142	validation_2-auc:0.79234
# [24]	validation_0-auc:0.82548	validation_1-auc:0.80143	validation_2-auc:0.79328
# [25]	validation_0-auc:0.82712	validation_1-auc:0.80228	validation_2-auc:0.79384
# [26]	validation_0-auc:0.82877	validation_1-auc:0.80302	validation_2-auc:0.79469
# [27]	validation_0-auc:0.83011	validation_1-auc:0.80359	validation_2-auc:0.79518
# [28]	validation_0-auc:0.83081	validation_1-auc:0.80395	validation_2-auc:0.79572
# [29]	validation_0-auc:0.83183	validation_1-auc:0.80454	validation_2-auc:0.79647
# [30]	validation_0-auc:0.83287	validation_1-auc:0.80516	validation_2-auc:0.79683
# [31]	validation_0-auc:0.83338	validation_1-auc:0.80555	validation_2-auc:0.79714
# [32]	validation_0-auc:0.83469	validation_1-auc:0.80601	validation_2-auc:0.79795
# [33]	validation_0-auc:0.83517	validation_1-auc:0.80653	validation_2-auc:0.79830
# [34]	validation_0-auc:0.83631	validation_1-auc:0.80686	validation_2-auc:0.79895
# [35]	validation_0-auc:0.83782	validation_1-auc:0.80775	validation_2-auc:0.79958
# [36]	validation_0-auc:0.83847	validation_1-auc:0.80794	validation_2-auc:0.80003
# [37]	validation_0-auc:0.83962	validation_1-auc:0.80835	validation_2-auc:0.80038
# [38]	validation_0-auc:0.84071	validation_1-auc:0.80884	validation_2-auc:0.80091
# [39]	validation_0-auc:0.84168	validation_1-auc:0.80897	validation_2-auc:0.80112
# [40]	validation_0-auc:0.84218	validation_1-auc:0.80901	validation_2-auc:0.80152
# [41]	validation_0-auc:0.84255	validation_1-auc:0.80932	validation_2-auc:0.80190
# [42]	validation_0-auc:0.84281	validation_1-auc:0.80977	validation_2-auc:0.80231
# [43]	validation_0-auc:0.84344	validation_1-auc:0.81009	validation_2-auc:0.80252
# [44]	validation_0-auc:0.84364	validation_1-auc:0.81024	validation_2-auc:0.80291
# [45]	validation_0-auc:0.84484	validation_1-auc:0.81070	validation_2-auc:0.80341
# [46]	validation_0-auc:0.84515	validation_1-auc:0.81087	validation_2-auc:0.80383
# [47]	validation_0-auc:0.84632	validation_1-auc:0.81122	validation_2-auc:0.80434
# [48]	validation_0-auc:0.84685	validation_1-auc:0.81122	validation_2-auc:0.80453
# [49]	validation_0-auc:0.84743	validation_1-auc:0.81141	validation_2-auc:0.80487
# [50]	validation_0-auc:0.84766	validation_1-auc:0.81157	validation_2-auc:0.80515
# [51]	validation_0-auc:0.84795	validation_1-auc:0.81178	validation_2-auc:0.80545
# [52]	validation_0-auc:0.84844	validation_1-auc:0.81198	validation_2-auc:0.80575
# [53]	validation_0-auc:0.84887	validation_1-auc:0.81205	validation_2-auc:0.80596
# [54]	validation_0-auc:0.84908	validation_1-auc:0.81207	validation_2-auc:0.80610
# [55]	validation_0-auc:0.84957	validation_1-auc:0.81214	validation_2-auc:0.80637
# [56]	validation_0-auc:0.84976	validation_1-auc:0.81234	validation_2-auc:0.80655
# [57]	validation_0-auc:0.85019	validation_1-auc:0.81235	validation_2-auc:0.80663
# [58]	validation_0-auc:0.85056	validation_1-auc:0.81242	validation_2-auc:0.80683
# [59]	validation_0-auc:0.85075	validation_1-auc:0.81248	validation_2-auc:0.80705
# [60]	validation_0-auc:0.85110	validation_1-auc:0.81267	validation_2-auc:0.80727
# [61]	validation_0-auc:0.85148	validation_1-auc:0.81277	validation_2-auc:0.80751
# [62]	validation_0-auc:0.85154	validation_1-auc:0.81296	validation_2-auc:0.80770
# [63]	validation_0-auc:0.85253	validation_1-auc:0.81309	validation_2-auc:0.80801
# [64]	validation_0-auc:0.85275	validation_1-auc:0.81299	validation_2-auc:0.80813
# [65]	validation_0-auc:0.85311	validation_1-auc:0.81308	validation_2-auc:0.80819
# [66]	validation_0-auc:0.85323	validation_1-auc:0.81316	validation_2-auc:0.80824
# [67]	validation_0-auc:0.85383	validation_1-auc:0.81337	validation_2-auc:0.80849
# [68]	validation_0-auc:0.85398	validation_1-auc:0.81348	validation_2-auc:0.80858
# [69]	validation_0-auc:0.85411	validation_1-auc:0.81358	validation_2-auc:0.80877
# [70]	validation_0-auc:0.85427	validation_1-auc:0.81371	validation_2-auc:0.80904
# [71]	validation_0-auc:0.85442	validation_1-auc:0.81366	validation_2-auc:0.80914
# [72]	validation_0-auc:0.85467	validation_1-auc:0.81376	validation_2-auc:0.80933
# [73]	validation_0-auc:0.85489	validation_1-auc:0.81388	validation_2-auc:0.80950
# [74]	validation_0-auc:0.85509	validation_1-auc:0.81378	validation_2-auc:0.80958
# [75]	validation_0-auc:0.85530	validation_1-auc:0.81399	validation_2-auc:0.80968
# [76]	validation_0-auc:0.85554	validation_1-auc:0.81410	validation_2-auc:0.80969
# [77]	validation_0-auc:0.85621	validation_1-auc:0.81416	validation_2-auc:0.80991
# [78]	validation_0-auc:0.85644	validation_1-auc:0.81423	validation_2-auc:0.80992
# [79]	validation_0-auc:0.85651	validation_1-auc:0.81430	validation_2-auc:0.81010
# [80]	validation_0-auc:0.85717	validation_1-auc:0.81436	validation_2-auc:0.81025
# [81]	validation_0-auc:0.85726	validation_1-auc:0.81446	validation_2-auc:0.81036
# [82]	validation_0-auc:0.85749	validation_1-auc:0.81459	validation_2-auc:0.81051
# [83]	validation_0-auc:0.85844	validation_1-auc:0.81447	validation_2-auc:0.81060
# [84]	validation_0-auc:0.85855	validation_1-auc:0.81448	validation_2-auc:0.81066
# [85]	validation_0-auc:0.85870	validation_1-auc:0.81444	validation_2-auc:0.81080
# [86]	validation_0-auc:0.85904	validation_1-auc:0.81460	validation_2-auc:0.81087
# [87]	validation_0-auc:0.85944	validation_1-auc:0.81458	validation_2-auc:0.81088
# [88]	validation_0-auc:0.85951	validation_1-auc:0.81462	validation_2-auc:0.81098
# [89]	validation_0-auc:0.85972	validation_1-auc:0.81473	validation_2-auc:0.81099
# [90]	validation_0-auc:0.86024	validation_1-auc:0.81488	validation_2-auc:0.81123
# [91]	validation_0-auc:0.86047	validation_1-auc:0.81498	validation_2-auc:0.81127
# [92]	validation_0-auc:0.86100	validation_1-auc:0.81508	validation_2-auc:0.81130
# [93]	validation_0-auc:0.86114	validation_1-auc:0.81513	validation_2-auc:0.81135
# [94]	validation_0-auc:0.86186	validation_1-auc:0.81518	validation_2-auc:0.81150
# [95]	validation_0-auc:0.86192	validation_1-auc:0.81520	validation_2-auc:0.81161
# [96]	validation_0-auc:0.86211	validation_1-auc:0.81528	validation_2-auc:0.81165
# [97]	validation_0-auc:0.86360	validation_1-auc:0.81548	validation_2-auc:0.81180
# [98]	validation_0-auc:0.86445	validation_1-auc:0.81541	validation_2-auc:0.81198
# [99]	validation_0-auc:0.86457	validation_1-auc:0.81542	validation_2-auc:0.81207
# [100]	validation_0-auc:0.86460	validation_1-auc:0.81544	validation_2-auc:0.81209
# [101]	validation_0-auc:0.86518	validation_1-auc:0.81549	validation_2-auc:0.81224
# [102]	validation_0-auc:0.86520	validation_1-auc:0.81556	validation_2-auc:0.81229
# [103]	validation_0-auc:0.86520	validation_1-auc:0.81556	validation_2-auc:0.81231
# [104]	validation_0-auc:0.86541	validation_1-auc:0.81562	validation_2-auc:0.81237
# [105]	validation_0-auc:0.86593	validation_1-auc:0.81581	validation_2-auc:0.81263
# [106]	validation_0-auc:0.86670	validation_1-auc:0.81584	validation_2-auc:0.81279
# [107]	validation_0-auc:0.86677	validation_1-auc:0.81586	validation_2-auc:0.81283
# [108]	validation_0-auc:0.86747	validation_1-auc:0.81586	validation_2-auc:0.81292
# [109]	validation_0-auc:0.86799	validation_1-auc:0.81588	validation_2-auc:0.81310
# [110]	validation_0-auc:0.86873	validation_1-auc:0.81596	validation_2-auc:0.81313
# [111]	validation_0-auc:0.86876	validation_1-auc:0.81602	validation_2-auc:0.81320
# [112]	validation_0-auc:0.86885	validation_1-auc:0.81601	validation_2-auc:0.81320
# [113]	validation_0-auc:0.86903	validation_1-auc:0.81597	validation_2-auc:0.81323
# [114]	validation_0-auc:0.86950	validation_1-auc:0.81587	validation_2-auc:0.81332
# [115]	validation_0-auc:0.86952	validation_1-auc:0.81593	validation_2-auc:0.81333
# [116]	validation_0-auc:0.87031	validation_1-auc:0.81619	validation_2-auc:0.81361
# [117]	validation_0-auc:0.87073	validation_1-auc:0.81606	validation_2-auc:0.81369
# [118]	validation_0-auc:0.87113	validation_1-auc:0.81628	validation_2-auc:0.81378
# [119]	validation_0-auc:0.87193	validation_1-auc:0.81634	validation_2-auc:0.81387
# [120]	validation_0-auc:0.87233	validation_1-auc:0.81643	validation_2-auc:0.81395
# [121]	validation_0-auc:0.87256	validation_1-auc:0.81641	validation_2-auc:0.81396
# [122]	validation_0-auc:0.87283	validation_1-auc:0.81643	validation_2-auc:0.81405
# [123]	validation_0-auc:0.87379	validation_1-auc:0.81641	validation_2-auc:0.81410
# [124]	validation_0-auc:0.87395	validation_1-auc:0.81640	validation_2-auc:0.81414
# [125]	validation_0-auc:0.87447	validation_1-auc:0.81657	validation_2-auc:0.81433
# [126]	validation_0-auc:0.87511	validation_1-auc:0.81670	validation_2-auc:0.81429
# [127]	validation_0-auc:0.87513	validation_1-auc:0.81671	validation_2-auc:0.81427
# [128]	validation_0-auc:0.87525	validation_1-auc:0.81677	validation_2-auc:0.81432
# [129]	validation_0-auc:0.87568	validation_1-auc:0.81677	validation_2-auc:0.81432
# [130]	validation_0-auc:0.87617	validation_1-auc:0.81695	validation_2-auc:0.81449
# [131]	validation_0-auc:0.87713	validation_1-auc:0.81709	validation_2-auc:0.81461
# [132]	validation_0-auc:0.87788	validation_1-auc:0.81708	validation_2-auc:0.81457
# [133]	validation_0-auc:0.87807	validation_1-auc:0.81721	validation_2-auc:0.81467
# [134]	validation_0-auc:0.87855	validation_1-auc:0.81720	validation_2-auc:0.81470
# [135]	validation_0-auc:0.87888	validation_1-auc:0.81718	validation_2-auc:0.81470
# [136]	validation_0-auc:0.87901	validation_1-auc:0.81721	validation_2-auc:0.81473
# [137]	validation_0-auc:0.87908	validation_1-auc:0.81714	validation_2-auc:0.81474
# [138]	validation_0-auc:0.87928	validation_1-auc:0.81710	validation_2-auc:0.81476
# [139]	validation_0-auc:0.87938	validation_1-auc:0.81714	validation_2-auc:0.81477
# [140]	validation_0-auc:0.87948	validation_1-auc:0.81715	validation_2-auc:0.81482
# [141]	validation_0-auc:0.87962	validation_1-auc:0.81707	validation_2-auc:0.81494
# [142]	validation_0-auc:0.87990	validation_1-auc:0.81699	validation_2-auc:0.81488
# [143]	validation_0-auc:0.87997	validation_1-auc:0.81707	validation_2-auc:0.81491
# [144]	validation_0-auc:0.88061	validation_1-auc:0.81711	validation_2-auc:0.81496
# [145]	validation_0-auc:0.88134	validation_1-auc:0.81720	validation_2-auc:0.81507
# [146]	validation_0-auc:0.88147	validation_1-auc:0.81724	validation_2-auc:0.81513
# [147]	validation_0-auc:0.88163	validation_1-auc:0.81720	validation_2-auc:0.81513
# [148]	validation_0-auc:0.88205	validation_1-auc:0.81722	validation_2-auc:0.81524
# [149]	validation_0-auc:0.88224	validation_1-auc:0.81727	validation_2-auc:0.81533
# [150]	validation_0-auc:0.88233	validation_1-auc:0.81728	validation_2-auc:0.81533
# [151]	validation_0-auc:0.88283	validation_1-auc:0.81730	validation_2-auc:0.81536
# [152]	validation_0-auc:0.88285	validation_1-auc:0.81731	validation_2-auc:0.81539
# [153]	validation_0-auc:0.88287	validation_1-auc:0.81732	validation_2-auc:0.81540
# [154]	validation_0-auc:0.88348	validation_1-auc:0.81724	validation_2-auc:0.81549
# [155]	validation_0-auc:0.88408	validation_1-auc:0.81726	validation_2-auc:0.81552
# [156]	validation_0-auc:0.88422	validation_1-auc:0.81727	validation_2-auc:0.81548
# [157]	validation_0-auc:0.88459	validation_1-auc:0.81724	validation_2-auc:0.81545
# [158]	validation_0-auc:0.88465	validation_1-auc:0.81726	validation_2-auc:0.81550
# [159]	validation_0-auc:0.88537	validation_1-auc:0.81718	validation_2-auc:0.81558
# [160]	validation_0-auc:0.88569	validation_1-auc:0.81710	validation_2-auc:0.81557
# [161]	validation_0-auc:0.88568	validation_1-auc:0.81709	validation_2-auc:0.81556
# [162]	validation_0-auc:0.88570	validation_1-auc:0.81708	validation_2-auc:0.81557
# [163]	validation_0-auc:0.88588	validation_1-auc:0.81708	validation_2-auc:0.81559
# [164]	validation_0-auc:0.88598	validation_1-auc:0.81706	validation_2-auc:0.81553
# [165]	validation_0-auc:0.88642	validation_1-auc:0.81710	validation_2-auc:0.81550
# [166]	validation_0-auc:0.88649	validation_1-auc:0.81715	validation_2-auc:0.81557
# [167]	validation_0-auc:0.88661	validation_1-auc:0.81718	validation_2-auc:0.81560
# [168]	validation_0-auc:0.88679	validation_1-auc:0.81709	validation_2-auc:0.81559
# [169]	validation_0-auc:0.88683	validation_1-auc:0.81710	validation_2-auc:0.81559
# [170]	validation_0-auc:0.88687	validation_1-auc:0.81715	validation_2-auc:0.81562
# [171]	validation_0-auc:0.88727	validation_1-auc:0.81717	validation_2-auc:0.81550
# [172]	validation_0-auc:0.88725	validation_1-auc:0.81717	validation_2-auc:0.81551
# [173]	validation_0-auc:0.88764	validation_1-auc:0.81720	validation_2-auc:0.81553
# [174]	validation_0-auc:0.88767	validation_1-auc:0.81722	validation_2-auc:0.81556
# [175]	validation_0-auc:0.88801	validation_1-auc:0.81736	validation_2-auc:0.81563
# [176]	validation_0-auc:0.88802	validation_1-auc:0.81736	validation_2-auc:0.81563
# [177]	validation_0-auc:0.88859	validation_1-auc:0.81726	validation_2-auc:0.81566
# [178]	validation_0-auc:0.88906	validation_1-auc:0.81721	validation_2-auc:0.81570
# [179]	validation_0-auc:0.88962	validation_1-auc:0.81721	validation_2-auc:0.81555
# [180]	validation_0-auc:0.88977	validation_1-auc:0.81726	validation_2-auc:0.81558
# [181]	validation_0-auc:0.88979	validation_1-auc:0.81726	validation_2-auc:0.81556
# [182]	validation_0-auc:0.88988	validation_1-auc:0.81731	validation_2-auc:0.81560
# [183]	validation_0-auc:0.89041	validation_1-auc:0.81728	validation_2-auc:0.81559
# [184]	validation_0-auc:0.89074	validation_1-auc:0.81734	validation_2-auc:0.81568
# [185]	validation_0-auc:0.89117	validation_1-auc:0.81740	validation_2-auc:0.81561
# [186]	validation_0-auc:0.89141	validation_1-auc:0.81751	validation_2-auc:0.81562
# [187]	validation_0-auc:0.89152	validation_1-auc:0.81751	validation_2-auc:0.81562
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.045, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10000, n_jobs=None,
#               num_parallel_tree=None, random_state=1907, ...)

# %% [markdown]
# Model vyhodnocuje na základě AUC. Na validačním samplu dává nejlepší iterace accuracy 0.81570, na testu 0.81721. Výsledky modelu výše pro přehlednost zakreslíme do grafu:

# %%
metric = 'auc'
evals_result = booster_sklearn.evals_result()
fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn.best_score
best_iteration = booster_sklearn.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# plt.savefig('test.svg', format='svg')
# plt.close()

# %% [markdown]
# ## Vyhodnocení důležitosti jednotlivých prediktorů

# %% [markdown]
# Nyní se blíže podíváme na to, jakou důležitost v modelu mají jednotlivé prediktory a pokusíme se jejich počet zredukovat. Jako první vykreslujeme importance score napočítané přímo modelem:

# %%
outcomes = dict(zip(cols_pred,booster_sklearn.feature_importances_)).items()

importance_type = 'total_gain'

predictor_strength = sorted([(k, v) for k,v in outcomes], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = 17
plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:17])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:17])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %% [markdown]
# Dále pozorujeme vliv prediktorů na target prostřednictvím SHAP (SHapley Additive exPlanations) přístupu. Vidíme, že například vyšší počet požadavků vede ke snížení pravděpodobnosti, že zákazník rezervaci zruší, zatímco delší doba mezi provedením rezervace a časem příjezdu tuto pravděpodobnost naopak zvyšuje: (z důvodu vysoké výpočetní náročnosti sekci zakomentováváme)

# %%
# import shap
# shap.initjs()

# explainer = shap.TreeExplainer(booster_sklearn)
# shap_values = explainer.shap_values(data[cols_pred])

# plt.figure()
# shap.summary_plot(shap_values, data[cols_pred], max_display=20, show=True)
# plt.show()

# shap.force_plot(explainer.expected_value, shap_values[0,:], data[cols_pred].iloc[0,:])

# shap.plots._waterfall.waterfall_legacy(
#     expected_value=explainer.expected_value, 
#     shap_values=shap_values[0, :], 
#     feature_names=cols_pred, 
#     max_display=20
# )

# %% [markdown]
# Na základě výsledků výše jsme zkoušeli několik přístupů k tomu, jaké prediktory vyhodit a jaké v modelu ponechat. Jako nejlepší se nakonec jevil přístup "top 10", tedy ponechali jsme v modelu deset prediktorů s nejvyšším importance score spočteném v prvním modelu výše.

# %% [markdown]
# ## "Top 10" XGBoost model

# %%
cols_pred_top10 = [x for x in cols_pred if (x not in list(dict(sorted([(k, v) for k,v in outcomes], key = lambda x: x[1], reverse = True)[-7:]).keys()))]

# %% [markdown]
# Z vektoru prediktorů jsme tedy odebrali sedm proměnných s nejnižším importance score a zbylé prediktory jsme použili v následujícím modelu. Pomocí metody Grid Search jsme došli k závěru, že nejlepší výsledky dává model s nastavením hyperparametrů viz níže:

# %%
booster_sklearn_top10 = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=1907,
    verbosity=1,
    eval_metric='auc',
    use_label_encoder=False,
    early_stopping_rounds=20,
    max_depth = 9,
    learning_rate = 0.045,
    n_estimators=10000
)

booster_sklearn_top10.fit(
    data[train_mask][cols_pred_top10].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred_top10].values, data[train_mask][col_target].values),
        (data[test_mask][cols_pred_top10].values, data[test_mask][col_target].values),
        (data[valid_mask][cols_pred_top10].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.79718	validation_1-auc:0.78651	validation_2-auc:0.77355
# [1]	validation_0-auc:0.79845	validation_1-auc:0.78755	validation_2-auc:0.77516
# [2]	validation_0-auc:0.79936	validation_1-auc:0.78851	validation_2-auc:0.77599
# [3]	validation_0-auc:0.79971	validation_1-auc:0.78826	validation_2-auc:0.77631
# [4]	validation_0-auc:0.80105	validation_1-auc:0.78845	validation_2-auc:0.77740
# [5]	validation_0-auc:0.80104	validation_1-auc:0.78880	validation_2-auc:0.77802
# [6]	validation_0-auc:0.80520	validation_1-auc:0.79218	validation_2-auc:0.78072
# [7]	validation_0-auc:0.80809	validation_1-auc:0.79395	validation_2-auc:0.78284
# [8]	validation_0-auc:0.81021	validation_1-auc:0.79470	validation_2-auc:0.78474
# [9]	validation_0-auc:0.81200	validation_1-auc:0.79636	validation_2-auc:0.78658
# [10]	validation_0-auc:0.81245	validation_1-auc:0.79650	validation_2-auc:0.78717
# [11]	validation_0-auc:0.81346	validation_1-auc:0.79750	validation_2-auc:0.78766
# [12]	validation_0-auc:0.81372	validation_1-auc:0.79785	validation_2-auc:0.78834
# [13]	validation_0-auc:0.81475	validation_1-auc:0.79809	validation_2-auc:0.78919
# [14]	validation_0-auc:0.81578	validation_1-auc:0.79879	validation_2-auc:0.78905
# [15]	validation_0-auc:0.81640	validation_1-auc:0.79935	validation_2-auc:0.78954
# [16]	validation_0-auc:0.81724	validation_1-auc:0.80012	validation_2-auc:0.79018
# [17]	validation_0-auc:0.81787	validation_1-auc:0.80049	validation_2-auc:0.79062
# [18]	validation_0-auc:0.81875	validation_1-auc:0.80061	validation_2-auc:0.79132
# [19]	validation_0-auc:0.81906	validation_1-auc:0.80097	validation_2-auc:0.79160
# [20]	validation_0-auc:0.81961	validation_1-auc:0.80125	validation_2-auc:0.79215
# [21]	validation_0-auc:0.82002	validation_1-auc:0.80152	validation_2-auc:0.79240
# [22]	validation_0-auc:0.82094	validation_1-auc:0.80211	validation_2-auc:0.79278
# [23]	validation_0-auc:0.82100	validation_1-auc:0.80227	validation_2-auc:0.79294
# [24]	validation_0-auc:0.82125	validation_1-auc:0.80258	validation_2-auc:0.79306
# [25]	validation_0-auc:0.82309	validation_1-auc:0.80345	validation_2-auc:0.79388
# [26]	validation_0-auc:0.82437	validation_1-auc:0.80409	validation_2-auc:0.79492
# [27]	validation_0-auc:0.82577	validation_1-auc:0.80503	validation_2-auc:0.79538
# [28]	validation_0-auc:0.82605	validation_1-auc:0.80544	validation_2-auc:0.79588
# [29]	validation_0-auc:0.82727	validation_1-auc:0.80583	validation_2-auc:0.79635
# [30]	validation_0-auc:0.82830	validation_1-auc:0.80600	validation_2-auc:0.79704
# [31]	validation_0-auc:0.82950	validation_1-auc:0.80640	validation_2-auc:0.79748
# [32]	validation_0-auc:0.83069	validation_1-auc:0.80682	validation_2-auc:0.79822
# [33]	validation_0-auc:0.83197	validation_1-auc:0.80693	validation_2-auc:0.79852
# [34]	validation_0-auc:0.83283	validation_1-auc:0.80742	validation_2-auc:0.79924
# [35]	validation_0-auc:0.83362	validation_1-auc:0.80784	validation_2-auc:0.79984
# [36]	validation_0-auc:0.83486	validation_1-auc:0.80833	validation_2-auc:0.80023
# [37]	validation_0-auc:0.83513	validation_1-auc:0.80872	validation_2-auc:0.80058
# [38]	validation_0-auc:0.83628	validation_1-auc:0.80939	validation_2-auc:0.80102
# [39]	validation_0-auc:0.83711	validation_1-auc:0.80968	validation_2-auc:0.80173
# [40]	validation_0-auc:0.83757	validation_1-auc:0.80997	validation_2-auc:0.80196
# [41]	validation_0-auc:0.83806	validation_1-auc:0.81033	validation_2-auc:0.80233
# [42]	validation_0-auc:0.83847	validation_1-auc:0.81084	validation_2-auc:0.80268
# [43]	validation_0-auc:0.83960	validation_1-auc:0.81115	validation_2-auc:0.80294
# [44]	validation_0-auc:0.83992	validation_1-auc:0.81159	validation_2-auc:0.80334
# [45]	validation_0-auc:0.84010	validation_1-auc:0.81179	validation_2-auc:0.80370
# [46]	validation_0-auc:0.84030	validation_1-auc:0.81178	validation_2-auc:0.80394
# [47]	validation_0-auc:0.84098	validation_1-auc:0.81206	validation_2-auc:0.80420
# [48]	validation_0-auc:0.84112	validation_1-auc:0.81219	validation_2-auc:0.80425
# [49]	validation_0-auc:0.84154	validation_1-auc:0.81219	validation_2-auc:0.80437
# [50]	validation_0-auc:0.84200	validation_1-auc:0.81235	validation_2-auc:0.80473
# [51]	validation_0-auc:0.84261	validation_1-auc:0.81228	validation_2-auc:0.80483
# [52]	validation_0-auc:0.84297	validation_1-auc:0.81232	validation_2-auc:0.80506
# [53]	validation_0-auc:0.84316	validation_1-auc:0.81254	validation_2-auc:0.80532
# [54]	validation_0-auc:0.84358	validation_1-auc:0.81263	validation_2-auc:0.80535
# [55]	validation_0-auc:0.84395	validation_1-auc:0.81278	validation_2-auc:0.80556
# [56]	validation_0-auc:0.84406	validation_1-auc:0.81294	validation_2-auc:0.80586
# [57]	validation_0-auc:0.84442	validation_1-auc:0.81309	validation_2-auc:0.80609
# [58]	validation_0-auc:0.84481	validation_1-auc:0.81315	validation_2-auc:0.80625
# [59]	validation_0-auc:0.84515	validation_1-auc:0.81331	validation_2-auc:0.80655
# [60]	validation_0-auc:0.84523	validation_1-auc:0.81348	validation_2-auc:0.80673
# [61]	validation_0-auc:0.84534	validation_1-auc:0.81348	validation_2-auc:0.80685
# [62]	validation_0-auc:0.84621	validation_1-auc:0.81370	validation_2-auc:0.80709
# [63]	validation_0-auc:0.84652	validation_1-auc:0.81382	validation_2-auc:0.80735
# [64]	validation_0-auc:0.84677	validation_1-auc:0.81392	validation_2-auc:0.80764
# [65]	validation_0-auc:0.84696	validation_1-auc:0.81400	validation_2-auc:0.80769
# [66]	validation_0-auc:0.84702	validation_1-auc:0.81411	validation_2-auc:0.80775
# [67]	validation_0-auc:0.84712	validation_1-auc:0.81412	validation_2-auc:0.80783
# [68]	validation_0-auc:0.84770	validation_1-auc:0.81416	validation_2-auc:0.80783
# [69]	validation_0-auc:0.84777	validation_1-auc:0.81424	validation_2-auc:0.80793
# [70]	validation_0-auc:0.84835	validation_1-auc:0.81442	validation_2-auc:0.80811
# [71]	validation_0-auc:0.84840	validation_1-auc:0.81449	validation_2-auc:0.80808
# [72]	validation_0-auc:0.84855	validation_1-auc:0.81453	validation_2-auc:0.80817
# [73]	validation_0-auc:0.84864	validation_1-auc:0.81463	validation_2-auc:0.80824
# [74]	validation_0-auc:0.84879	validation_1-auc:0.81466	validation_2-auc:0.80836
# [75]	validation_0-auc:0.84898	validation_1-auc:0.81486	validation_2-auc:0.80838
# [76]	validation_0-auc:0.84966	validation_1-auc:0.81491	validation_2-auc:0.80849
# [77]	validation_0-auc:0.84967	validation_1-auc:0.81494	validation_2-auc:0.80855
# [78]	validation_0-auc:0.85013	validation_1-auc:0.81507	validation_2-auc:0.80859
# [79]	validation_0-auc:0.85068	validation_1-auc:0.81525	validation_2-auc:0.80890
# [80]	validation_0-auc:0.85082	validation_1-auc:0.81535	validation_2-auc:0.80902
# [81]	validation_0-auc:0.85102	validation_1-auc:0.81554	validation_2-auc:0.80913
# [82]	validation_0-auc:0.85111	validation_1-auc:0.81554	validation_2-auc:0.80925
# [83]	validation_0-auc:0.85219	validation_1-auc:0.81594	validation_2-auc:0.80923
# [84]	validation_0-auc:0.85252	validation_1-auc:0.81602	validation_2-auc:0.80938
# [85]	validation_0-auc:0.85284	validation_1-auc:0.81610	validation_2-auc:0.80945
# [86]	validation_0-auc:0.85286	validation_1-auc:0.81612	validation_2-auc:0.80951
# [87]	validation_0-auc:0.85298	validation_1-auc:0.81611	validation_2-auc:0.80946
# [88]	validation_0-auc:0.85297	validation_1-auc:0.81618	validation_2-auc:0.80952
# [89]	validation_0-auc:0.85402	validation_1-auc:0.81659	validation_2-auc:0.80972
# [90]	validation_0-auc:0.85426	validation_1-auc:0.81656	validation_2-auc:0.80966
# [91]	validation_0-auc:0.85442	validation_1-auc:0.81657	validation_2-auc:0.80973
# [92]	validation_0-auc:0.85459	validation_1-auc:0.81675	validation_2-auc:0.80989
# [93]	validation_0-auc:0.85563	validation_1-auc:0.81685	validation_2-auc:0.81009
# [94]	validation_0-auc:0.85565	validation_1-auc:0.81685	validation_2-auc:0.81017
# [95]	validation_0-auc:0.85568	validation_1-auc:0.81688	validation_2-auc:0.81018
# [96]	validation_0-auc:0.85654	validation_1-auc:0.81695	validation_2-auc:0.81037
# [97]	validation_0-auc:0.85724	validation_1-auc:0.81705	validation_2-auc:0.81035
# [98]	validation_0-auc:0.85727	validation_1-auc:0.81713	validation_2-auc:0.81038
# [99]	validation_0-auc:0.85820	validation_1-auc:0.81733	validation_2-auc:0.81059
# [100]	validation_0-auc:0.85834	validation_1-auc:0.81735	validation_2-auc:0.81066
# [101]	validation_0-auc:0.85860	validation_1-auc:0.81750	validation_2-auc:0.81078
# [102]	validation_0-auc:0.85916	validation_1-auc:0.81765	validation_2-auc:0.81092
# [103]	validation_0-auc:0.85954	validation_1-auc:0.81786	validation_2-auc:0.81111
# [104]	validation_0-auc:0.85974	validation_1-auc:0.81791	validation_2-auc:0.81124
# [105]	validation_0-auc:0.86000	validation_1-auc:0.81800	validation_2-auc:0.81135
# [106]	validation_0-auc:0.86088	validation_1-auc:0.81803	validation_2-auc:0.81130
# [107]	validation_0-auc:0.86097	validation_1-auc:0.81802	validation_2-auc:0.81137
# [108]	validation_0-auc:0.86096	validation_1-auc:0.81803	validation_2-auc:0.81139
# [109]	validation_0-auc:0.86117	validation_1-auc:0.81799	validation_2-auc:0.81139
# [110]	validation_0-auc:0.86202	validation_1-auc:0.81820	validation_2-auc:0.81155
# [111]	validation_0-auc:0.86211	validation_1-auc:0.81830	validation_2-auc:0.81156
# [112]	validation_0-auc:0.86271	validation_1-auc:0.81830	validation_2-auc:0.81163
# [113]	validation_0-auc:0.86282	validation_1-auc:0.81834	validation_2-auc:0.81173
# [114]	validation_0-auc:0.86357	validation_1-auc:0.81851	validation_2-auc:0.81189
# [115]	validation_0-auc:0.86376	validation_1-auc:0.81852	validation_2-auc:0.81194
# [116]	validation_0-auc:0.86384	validation_1-auc:0.81854	validation_2-auc:0.81207
# [117]	validation_0-auc:0.86402	validation_1-auc:0.81854	validation_2-auc:0.81202
# [118]	validation_0-auc:0.86454	validation_1-auc:0.81854	validation_2-auc:0.81202
# [119]	validation_0-auc:0.86464	validation_1-auc:0.81856	validation_2-auc:0.81207
# [120]	validation_0-auc:0.86468	validation_1-auc:0.81857	validation_2-auc:0.81203
# [121]	validation_0-auc:0.86471	validation_1-auc:0.81858	validation_2-auc:0.81205
# [122]	validation_0-auc:0.86501	validation_1-auc:0.81858	validation_2-auc:0.81210
# [123]	validation_0-auc:0.86503	validation_1-auc:0.81862	validation_2-auc:0.81207
# [124]	validation_0-auc:0.86508	validation_1-auc:0.81865	validation_2-auc:0.81210
# [125]	validation_0-auc:0.86585	validation_1-auc:0.81877	validation_2-auc:0.81224
# [126]	validation_0-auc:0.86609	validation_1-auc:0.81882	validation_2-auc:0.81232
# [127]	validation_0-auc:0.86639	validation_1-auc:0.81886	validation_2-auc:0.81237
# [128]	validation_0-auc:0.86644	validation_1-auc:0.81889	validation_2-auc:0.81241
# [129]	validation_0-auc:0.86671	validation_1-auc:0.81891	validation_2-auc:0.81239
# [130]	validation_0-auc:0.86678	validation_1-auc:0.81891	validation_2-auc:0.81242
# [131]	validation_0-auc:0.86748	validation_1-auc:0.81901	validation_2-auc:0.81247
# [132]	validation_0-auc:0.86786	validation_1-auc:0.81902	validation_2-auc:0.81258
# [133]	validation_0-auc:0.86792	validation_1-auc:0.81905	validation_2-auc:0.81265
# [134]	validation_0-auc:0.86817	validation_1-auc:0.81916	validation_2-auc:0.81269
# [135]	validation_0-auc:0.86845	validation_1-auc:0.81912	validation_2-auc:0.81272
# [136]	validation_0-auc:0.86913	validation_1-auc:0.81924	validation_2-auc:0.81287
# [137]	validation_0-auc:0.86921	validation_1-auc:0.81931	validation_2-auc:0.81290
# [138]	validation_0-auc:0.86944	validation_1-auc:0.81935	validation_2-auc:0.81297
# [139]	validation_0-auc:0.86973	validation_1-auc:0.81952	validation_2-auc:0.81302
# [140]	validation_0-auc:0.86990	validation_1-auc:0.81954	validation_2-auc:0.81309
# [141]	validation_0-auc:0.87024	validation_1-auc:0.81954	validation_2-auc:0.81306
# [142]	validation_0-auc:0.87049	validation_1-auc:0.81974	validation_2-auc:0.81314
# [143]	validation_0-auc:0.87116	validation_1-auc:0.81984	validation_2-auc:0.81326
# [144]	validation_0-auc:0.87142	validation_1-auc:0.81981	validation_2-auc:0.81326
# [145]	validation_0-auc:0.87144	validation_1-auc:0.81984	validation_2-auc:0.81327
# [146]	validation_0-auc:0.87224	validation_1-auc:0.81999	validation_2-auc:0.81346
# [147]	validation_0-auc:0.87225	validation_1-auc:0.82000	validation_2-auc:0.81351
# [148]	validation_0-auc:0.87245	validation_1-auc:0.82005	validation_2-auc:0.81355
# [149]	validation_0-auc:0.87292	validation_1-auc:0.82015	validation_2-auc:0.81365
# [150]	validation_0-auc:0.87356	validation_1-auc:0.82023	validation_2-auc:0.81373
# [151]	validation_0-auc:0.87416	validation_1-auc:0.82028	validation_2-auc:0.81384
# [152]	validation_0-auc:0.87422	validation_1-auc:0.82034	validation_2-auc:0.81392
# [153]	validation_0-auc:0.87439	validation_1-auc:0.82041	validation_2-auc:0.81397
# [154]	validation_0-auc:0.87472	validation_1-auc:0.82055	validation_2-auc:0.81405
# [155]	validation_0-auc:0.87484	validation_1-auc:0.82060	validation_2-auc:0.81409
# [156]	validation_0-auc:0.87542	validation_1-auc:0.82058	validation_2-auc:0.81413
# [157]	validation_0-auc:0.87545	validation_1-auc:0.82060	validation_2-auc:0.81417
# [158]	validation_0-auc:0.87643	validation_1-auc:0.82057	validation_2-auc:0.81432
# [159]	validation_0-auc:0.87644	validation_1-auc:0.82057	validation_2-auc:0.81437
# [160]	validation_0-auc:0.87673	validation_1-auc:0.82052	validation_2-auc:0.81436
# [161]	validation_0-auc:0.87694	validation_1-auc:0.82053	validation_2-auc:0.81440
# [162]	validation_0-auc:0.87771	validation_1-auc:0.82063	validation_2-auc:0.81457
# [163]	validation_0-auc:0.87787	validation_1-auc:0.82076	validation_2-auc:0.81465
# [164]	validation_0-auc:0.87797	validation_1-auc:0.82081	validation_2-auc:0.81466
# [165]	validation_0-auc:0.87815	validation_1-auc:0.82095	validation_2-auc:0.81465
# [166]	validation_0-auc:0.87854	validation_1-auc:0.82094	validation_2-auc:0.81468
# [167]	validation_0-auc:0.87887	validation_1-auc:0.82093	validation_2-auc:0.81467
# [168]	validation_0-auc:0.87964	validation_1-auc:0.82098	validation_2-auc:0.81470
# [169]	validation_0-auc:0.87969	validation_1-auc:0.82100	validation_2-auc:0.81472
# [170]	validation_0-auc:0.88002	validation_1-auc:0.82102	validation_2-auc:0.81477
# [171]	validation_0-auc:0.88014	validation_1-auc:0.82102	validation_2-auc:0.81478
# [172]	validation_0-auc:0.88020	validation_1-auc:0.82106	validation_2-auc:0.81481
# [173]	validation_0-auc:0.88045	validation_1-auc:0.82113	validation_2-auc:0.81487
# [174]	validation_0-auc:0.88051	validation_1-auc:0.82116	validation_2-auc:0.81494
# [175]	validation_0-auc:0.88073	validation_1-auc:0.82121	validation_2-auc:0.81507
# [176]	validation_0-auc:0.88102	validation_1-auc:0.82119	validation_2-auc:0.81498
# [177]	validation_0-auc:0.88148	validation_1-auc:0.82118	validation_2-auc:0.81505
# [178]	validation_0-auc:0.88150	validation_1-auc:0.82123	validation_2-auc:0.81509
# [179]	validation_0-auc:0.88156	validation_1-auc:0.82124	validation_2-auc:0.81509
# [180]	validation_0-auc:0.88165	validation_1-auc:0.82128	validation_2-auc:0.81514
# [181]	validation_0-auc:0.88170	validation_1-auc:0.82129	validation_2-auc:0.81512
# [182]	validation_0-auc:0.88184	validation_1-auc:0.82130	validation_2-auc:0.81509
# [183]	validation_0-auc:0.88215	validation_1-auc:0.82131	validation_2-auc:0.81508
# [184]	validation_0-auc:0.88221	validation_1-auc:0.82129	validation_2-auc:0.81507
# [185]	validation_0-auc:0.88226	validation_1-auc:0.82132	validation_2-auc:0.81509
# [186]	validation_0-auc:0.88230	validation_1-auc:0.82131	validation_2-auc:0.81506
# [187]	validation_0-auc:0.88246	validation_1-auc:0.82135	validation_2-auc:0.81505
# [188]	validation_0-auc:0.88268	validation_1-auc:0.82132	validation_2-auc:0.81499
# [189]	validation_0-auc:0.88295	validation_1-auc:0.82128	validation_2-auc:0.81503
# [190]	validation_0-auc:0.88340	validation_1-auc:0.82138	validation_2-auc:0.81511
# [191]	validation_0-auc:0.88344	validation_1-auc:0.82143	validation_2-auc:0.81510
# [192]	validation_0-auc:0.88370	validation_1-auc:0.82156	validation_2-auc:0.81523
# [193]	validation_0-auc:0.88441	validation_1-auc:0.82166	validation_2-auc:0.81532
# [194]	validation_0-auc:0.88455	validation_1-auc:0.82167	validation_2-auc:0.81531
# [195]	validation_0-auc:0.88462	validation_1-auc:0.82170	validation_2-auc:0.81531
# [196]	validation_0-auc:0.88465	validation_1-auc:0.82170	validation_2-auc:0.81533
# [197]	validation_0-auc:0.88471	validation_1-auc:0.82169	validation_2-auc:0.81534
# [198]	validation_0-auc:0.88491	validation_1-auc:0.82165	validation_2-auc:0.81527
# [199]	validation_0-auc:0.88519	validation_1-auc:0.82162	validation_2-auc:0.81521
# [200]	validation_0-auc:0.88543	validation_1-auc:0.82169	validation_2-auc:0.81522
# [201]	validation_0-auc:0.88564	validation_1-auc:0.82172	validation_2-auc:0.81521
# [202]	validation_0-auc:0.88570	validation_1-auc:0.82169	validation_2-auc:0.81519
# [203]	validation_0-auc:0.88592	validation_1-auc:0.82177	validation_2-auc:0.81515
# [204]	validation_0-auc:0.88603	validation_1-auc:0.82183	validation_2-auc:0.81514
# [205]	validation_0-auc:0.88627	validation_1-auc:0.82192	validation_2-auc:0.81512
# [206]	validation_0-auc:0.88651	validation_1-auc:0.82200	validation_2-auc:0.81513
# [207]	validation_0-auc:0.88657	validation_1-auc:0.82205	validation_2-auc:0.81515
# [208]	validation_0-auc:0.88662	validation_1-auc:0.82207	validation_2-auc:0.81518
# [209]	validation_0-auc:0.88667	validation_1-auc:0.82211	validation_2-auc:0.81518
# [210]	validation_0-auc:0.88683	validation_1-auc:0.82201	validation_2-auc:0.81511
# [211]	validation_0-auc:0.88743	validation_1-auc:0.82214	validation_2-auc:0.81525
# [212]	validation_0-auc:0.88786	validation_1-auc:0.82218	validation_2-auc:0.81515
# [213]	validation_0-auc:0.88792	validation_1-auc:0.82222	validation_2-auc:0.81514
# [214]	validation_0-auc:0.88797	validation_1-auc:0.82222	validation_2-auc:0.81516
# [215]	validation_0-auc:0.88840	validation_1-auc:0.82231	validation_2-auc:0.81529
# [216]	validation_0-auc:0.88870	validation_1-auc:0.82234	validation_2-auc:0.81524
# [217]	validation_0-auc:0.88891	validation_1-auc:0.82244	validation_2-auc:0.81537
# [218]	validation_0-auc:0.88942	validation_1-auc:0.82242	validation_2-auc:0.81533
# [219]	validation_0-auc:0.88948	validation_1-auc:0.82243	validation_2-auc:0.81532
# [220]	validation_0-auc:0.88953	validation_1-auc:0.82246	validation_2-auc:0.81530
# [221]	validation_0-auc:0.88998	validation_1-auc:0.82256	validation_2-auc:0.81541
# [222]	validation_0-auc:0.89009	validation_1-auc:0.82256	validation_2-auc:0.81538
# [223]	validation_0-auc:0.89033	validation_1-auc:0.82261	validation_2-auc:0.81541
# [224]	validation_0-auc:0.89040	validation_1-auc:0.82262	validation_2-auc:0.81538
# [225]	validation_0-auc:0.89054	validation_1-auc:0.82261	validation_2-auc:0.81537
# [226]	validation_0-auc:0.89117	validation_1-auc:0.82262	validation_2-auc:0.81541
# [227]	validation_0-auc:0.89122	validation_1-auc:0.82261	validation_2-auc:0.81543
# [228]	validation_0-auc:0.89128	validation_1-auc:0.82261	validation_2-auc:0.81541
# [229]	validation_0-auc:0.89139	validation_1-auc:0.82262	validation_2-auc:0.81544
# [230]	validation_0-auc:0.89145	validation_1-auc:0.82266	validation_2-auc:0.81551
# [231]	validation_0-auc:0.89189	validation_1-auc:0.82274	validation_2-auc:0.81565
# [232]	validation_0-auc:0.89197	validation_1-auc:0.82273	validation_2-auc:0.81563
# [233]	validation_0-auc:0.89237	validation_1-auc:0.82278	validation_2-auc:0.81575
# [234]	validation_0-auc:0.89298	validation_1-auc:0.82294	validation_2-auc:0.81590
# [235]	validation_0-auc:0.89303	validation_1-auc:0.82298	validation_2-auc:0.81590
# [236]	validation_0-auc:0.89313	validation_1-auc:0.82300	validation_2-auc:0.81587
# [237]	validation_0-auc:0.89357	validation_1-auc:0.82305	validation_2-auc:0.81582
# [238]	validation_0-auc:0.89360	validation_1-auc:0.82304	validation_2-auc:0.81582
# [239]	validation_0-auc:0.89363	validation_1-auc:0.82308	validation_2-auc:0.81582
# [240]	validation_0-auc:0.89370	validation_1-auc:0.82305	validation_2-auc:0.81580
# [241]	validation_0-auc:0.89390	validation_1-auc:0.82304	validation_2-auc:0.81580
# [242]	validation_0-auc:0.89396	validation_1-auc:0.82307	validation_2-auc:0.81576
# [243]	validation_0-auc:0.89412	validation_1-auc:0.82301	validation_2-auc:0.81574
# [244]	validation_0-auc:0.89441	validation_1-auc:0.82301	validation_2-auc:0.81572
# [245]	validation_0-auc:0.89445	validation_1-auc:0.82298	validation_2-auc:0.81570
# [246]	validation_0-auc:0.89457	validation_1-auc:0.82299	validation_2-auc:0.81568
# [247]	validation_0-auc:0.89484	validation_1-auc:0.82305	validation_2-auc:0.81582
# [248]	validation_0-auc:0.89495	validation_1-auc:0.82309	validation_2-auc:0.81579
# [249]	validation_0-auc:0.89503	validation_1-auc:0.82309	validation_2-auc:0.81579
# [250]	validation_0-auc:0.89543	validation_1-auc:0.82327	validation_2-auc:0.81589
# [251]	validation_0-auc:0.89608	validation_1-auc:0.82339	validation_2-auc:0.81596
# [252]	validation_0-auc:0.89615	validation_1-auc:0.82337	validation_2-auc:0.81593
# [253]	validation_0-auc:0.89651	validation_1-auc:0.82337	validation_2-auc:0.81596
# [254]	validation_0-auc:0.89652	validation_1-auc:0.82341	validation_2-auc:0.81598
# [255]	validation_0-auc:0.89663	validation_1-auc:0.82345	validation_2-auc:0.81603
# [256]	validation_0-auc:0.89690	validation_1-auc:0.82350	validation_2-auc:0.81609
# [257]	validation_0-auc:0.89716	validation_1-auc:0.82353	validation_2-auc:0.81612
# [258]	validation_0-auc:0.89726	validation_1-auc:0.82354	validation_2-auc:0.81615
# [259]	validation_0-auc:0.89755	validation_1-auc:0.82357	validation_2-auc:0.81622
# [260]	validation_0-auc:0.89768	validation_1-auc:0.82357	validation_2-auc:0.81619
# [261]	validation_0-auc:0.89794	validation_1-auc:0.82357	validation_2-auc:0.81624
# [262]	validation_0-auc:0.89804	validation_1-auc:0.82364	validation_2-auc:0.81624
# [263]	validation_0-auc:0.89825	validation_1-auc:0.82366	validation_2-auc:0.81623
# [264]	validation_0-auc:0.89830	validation_1-auc:0.82368	validation_2-auc:0.81621
# [265]	validation_0-auc:0.89842	validation_1-auc:0.82371	validation_2-auc:0.81620
# [266]	validation_0-auc:0.89846	validation_1-auc:0.82371	validation_2-auc:0.81618
# [267]	validation_0-auc:0.89854	validation_1-auc:0.82374	validation_2-auc:0.81615
# [268]	validation_0-auc:0.89891	validation_1-auc:0.82378	validation_2-auc:0.81608
# [269]	validation_0-auc:0.89895	validation_1-auc:0.82377	validation_2-auc:0.81609
# [270]	validation_0-auc:0.89901	validation_1-auc:0.82373	validation_2-auc:0.81605
# [271]	validation_0-auc:0.89908	validation_1-auc:0.82372	validation_2-auc:0.81601
# [272]	validation_0-auc:0.89913	validation_1-auc:0.82370	validation_2-auc:0.81598
# [273]	validation_0-auc:0.89933	validation_1-auc:0.82376	validation_2-auc:0.81588
# [274]	validation_0-auc:0.89948	validation_1-auc:0.82382	validation_2-auc:0.81594
# [275]	validation_0-auc:0.89956	validation_1-auc:0.82381	validation_2-auc:0.81593
# [276]	validation_0-auc:0.89971	validation_1-auc:0.82384	validation_2-auc:0.81596
# [277]	validation_0-auc:0.89976	validation_1-auc:0.82378	validation_2-auc:0.81592
# [278]	validation_0-auc:0.89986	validation_1-auc:0.82377	validation_2-auc:0.81589
# [279]	validation_0-auc:0.90001	validation_1-auc:0.82383	validation_2-auc:0.81587
# [280]	validation_0-auc:0.90030	validation_1-auc:0.82388	validation_2-auc:0.81587
# [281]	validation_0-auc:0.90046	validation_1-auc:0.82391	validation_2-auc:0.81584
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=20,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.045, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10000, n_jobs=None,
#               num_parallel_tree=None, random_state=1907, ...)

# %% [markdown]
# Na validačním samplu dává nejlepší iterace v tomto případě accuracy 0.81624 (na testu 0.82364). Opět vyobrazeno viz níže:

# %%
metric = 'auc'
evals_result = booster_sklearn_top10.evals_result()
fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn_top10.best_score
best_iteration = booster_sklearn_top10.best_iteration+2

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# plt.savefig('test.svg', format='svg')
# plt.close()

# %% [markdown]
# ## Kaggle predikce

# %% [markdown]
# Na závěr načteme data, pro které máme predikovat.

# %%
data_file = Path("../Data/2024_DS2_HW1_data_test.csv")
data_kaggle = pd.read_csv(data_file, sep = ',', decimal = '.', index_col = 'Booking_ID')

# %%
data_kaggle
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN04969             2.0             NaN                   1.0
# INN34541             2.0             0.0                   NaN
# INN36109             2.0             NaN                   NaN
# INN01554             2.0             NaN                   0.0
# INN24975             2.0             NaN                   NaN
# ...                  ...             ...                   ...
# INN29523             1.0             NaN                   NaN
# INN25061             2.0             NaN                   1.0
# INN08475             2.0             NaN                   NaN
# INN13558             1.0             NaN                   NaN
# INN00626             2.0             NaN                   0.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN04969                  0.0       Meal Plan 1                         NaN
# INN34541                  2.0       Meal Plan 1                         0.0
# INN36109                  2.0       Meal Plan 1                         0.0
# INN01554                  3.0               NaN                         0.0
# INN24975                  NaN               NaN                         0.0
# ...                       ...               ...                         ...
# INN29523                  2.0       Meal Plan 2                         0.0
# INN25061                  NaN      Not Selected                         0.0
# INN08475                  NaN               NaN                         NaN
# INN13558                  0.0       Meal Plan 1                         NaN
# INN00626                  4.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN04969                  NaN        NaN        2017.0            8.0
# INN34541                  NaN        NaN        2018.0            2.0
# INN36109                  NaN        NaN        2018.0           12.0
# INN01554                  NaN        NaN        2018.0            6.0
# INN24975                  NaN        NaN        2018.0            9.0
# ...                       ...        ...           ...            ...
# INN29523          Room_Type 1       39.0        2017.0            8.0
# INN25061                  NaN        NaN        2018.0            6.0
# INN08475                  NaN      308.0        2018.0           11.0
# INN13558                  NaN        NaN        2018.0            7.0
# INN00626          Room_Type 4        NaN        2017.0           10.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN04969            23.0                 NaN             NaN
# INN34541             NaN             Offline             NaN
# INN36109             NaN                 NaN             NaN
# INN01554            21.0              Online             NaN
# INN24975             NaN                 NaN             NaN
# ...                  ...                 ...             ...
# INN29523             NaN             Offline             NaN
# INN25061             NaN              Online             0.0
# INN08475             NaN              Online             NaN
# INN13558            24.0                 NaN             NaN
# INN00626             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN04969                             0.0
# INN34541                             0.0
# INN36109                             0.0
# INN01554                             0.0
# INN24975                             0.0
# ...                                  ...
# INN29523                             0.0
# INN25061                             0.0
# INN08475                             0.0
# INN13558                             3.0
# INN00626                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN04969                                     NaN                 NaN
# INN34541                                     0.0                 NaN
# INN36109                                     NaN                 NaN
# INN01554                                     0.0                 NaN
# INN24975                                     NaN                 NaN
# ...                                          ...                 ...
# INN29523                                     NaN               87.00
# INN25061                                     NaN                 NaN
# INN08475                                     0.0               78.30
# INN13558                                    39.0                 NaN
# INN00626                                     0.0               87.54
#
#             no_of_special_requests
# Booking_ID
# INN04969                       3.0
# INN34541                       NaN
# INN36109                       NaN
# INN01554                       0.0
# INN24975                       2.0
# ...                            ...
# INN29523                       NaN
# INN25061                       NaN
# INN08475                       NaN
# INN13558                       0.0
# INN00626                       NaN
#
# [3593 rows x 17 columns]

# %% [markdown]
# Data upravíme a enkódujeme stejným způsobem jako výše.

# %%
mapping = {0.0: 'No', 1.0: 'Yes'}
data_kaggle['required_car_parking_space'] = data_kaggle['required_car_parking_space'].map(mapping)
data_kaggle['repeated_guest'] = data_kaggle['repeated_guest'].map(mapping)

# %%
mapping = {'Meal Plan 2': 0.42501087, 'Meal Plan 1': 0.31247541, 'Not Selected': 0.33476213, 'Meal Plan 3': 0.32749285}
data_kaggle['MTE_type_of_meal_plan'] = data_kaggle['type_of_meal_plan'].map(mapping)

# %%
mapping = {'No': 0.33115405, 'Yes': 0.17273773}
data_kaggle['MTE_required_car_parking_space'] = data_kaggle['required_car_parking_space'].map(mapping)

# %%
values = np.array([0.37680524, 0.32462439, 0.32859589, 0.33390951, 0.31724109, 0.31384923, 0.32403984])
labels = np.array(['Room_Type 6', 'Room_Type 1', 'Room_Type 4', 'Room_Type 2', 'Room_Type 5', 'Room_Type 7', 'Room_Type 3'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_room_type_reserved'] = data_kaggle['room_type_reserved'].map(mapping)

# %%
values = np.array([0.36860829, 0.30569387, 0.31800141, 0.19553228, 0.15616035])
labels = np.array(['Online', 'Offline', 'Aviation', 'Complementary', 'Corporate'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_market_segment_type'] = data_kaggle['market_segment_type'].map(mapping)

# %%
values = np.array([0.34633785, 0.21505483])
labels = np.array(['No','Yes'])

mapping = {label: value for value, label in zip(values, labels)}

data_kaggle['MTE_repeated_guest'] = data_kaggle['repeated_guest'].map(mapping)

# %%
data_kaggle.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN04969             2.0             NaN                   1.0
# INN34541             2.0             0.0                   NaN
# INN36109             2.0             NaN                   NaN
# INN01554             2.0             NaN                   0.0
# INN24975             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan required_car_parking_space  \
# Booking_ID
# INN04969                  0.0       Meal Plan 1                        NaN
# INN34541                  2.0       Meal Plan 1                         No
# INN36109                  2.0       Meal Plan 1                         No
# INN01554                  3.0               NaN                         No
# INN24975                  NaN               NaN                         No
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  ...  \
# Booking_ID                                                             ...
# INN04969                  NaN        NaN        2017.0            8.0  ...
# INN34541                  NaN        NaN        2018.0            2.0  ...
# INN36109                  NaN        NaN        2018.0           12.0  ...
# INN01554                  NaN        NaN        2018.0            6.0  ...
# INN24975                  NaN        NaN        2018.0            9.0  ...
#
#             repeated_guest no_of_previous_cancellations  \
# Booking_ID
# INN04969               NaN                          0.0
# INN34541               NaN                          0.0
# INN36109               NaN                          0.0
# INN01554               NaN                          0.0
# INN24975               NaN                          0.0
#
#            no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN04969                                    NaN                 NaN
# INN34541                                    0.0                 NaN
# INN36109                                    NaN                 NaN
# INN01554                                    0.0                 NaN
# INN24975                                    NaN                 NaN
#
#             no_of_special_requests  MTE_type_of_meal_plan  \
# Booking_ID
# INN04969                       3.0               0.312475
# INN34541                       NaN               0.312475
# INN36109                       NaN               0.312475
# INN01554                       0.0                    NaN
# INN24975                       2.0                    NaN
#
#             MTE_required_car_parking_space  MTE_room_type_reserved  \
# Booking_ID
# INN04969                               NaN                     NaN
# INN34541                          0.331154                     NaN
# INN36109                          0.331154                     NaN
# INN01554                          0.331154                     NaN
# INN24975                          0.331154                     NaN
#
#             MTE_market_segment_type  MTE_repeated_guest
# Booking_ID
# INN04969                        NaN                 NaN
# INN34541                   0.305694                 NaN
# INN36109                        NaN                 NaN
# INN01554                   0.368608                 NaN
# INN24975                        NaN                 NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Nakonec spočteme predikce pomocí finálního modelu a vygenerujeme csv soubor:

# %%
predictions_sklearn_top10 = booster_sklearn_top10.predict_proba(data_kaggle[cols_pred_top10],iteration_range=(0,booster_sklearn_top10.best_iteration))
print(predictions_sklearn_top10[:, 1])

predictions_sklearn_top10_2 = booster_sklearn_top10.predict_proba(data_kaggle[cols_pred_top10],iteration_range=(0,265))
print(predictions_sklearn_top10[:, 1])

predictions_sklearn_top10_3 = booster_sklearn_top10.predict_proba(data_kaggle[cols_pred_top10],iteration_range=(0,264))
print(predictions_sklearn_top10[:, 1])
# Out:
# [0.00320143 0.18730856 0.11090538 ... 0.90087    0.00764232 0.18634652]
# [0.00320143 0.18730856 0.11090538 ... 0.90087    0.00764232 0.18634652]
# [0.00320143 0.18730856 0.11090538 ... 0.90087    0.00764232 0.18634652]
# [1.9797155e-04 6.0037635e-02 8.2660906e-02 ... 9.9802184e-01 5.7832450e-03
#  1.3795293e-02]

# %%
csv_file = 'solution.csv'

pred_data = {
    'Booking_ID': data_kaggle.index,
    'booking_status': predictions_sklearn_top10_3[:, 1],
}
# Creating a DataFrame
df = pd.DataFrame(pred_data)

# File path to save the CSV
csv_file = 'solution.csv'

# Writing to the CSV file
df.to_csv(csv_file, index=False)

print("CSV file generated successfully.")
# Out:
# CSV file generated successfully.

# %% [markdown]
# ## Závěr

# %% [markdown]
# Modelovali jsme pravděpodobnost zrušení rezervace pomocí XGBoost Classifier. Došli jsme k tomu, že nejlepší výsledky dává model, který využívá pouze prvních deset prediktorů z hlediska importance score získaného v modelu využívajícím všechny prediktory. Hyperparametry našeho finálního modelu jsou nastaveny následovně:
#
# - maximální hloubka stromu: 9
# - learning rate: 0.045
# - early stopping: 20
# - ostatní parametry: defaultní nastavení

# %% [markdown]
# ## Výsledky - Kaggle

# %% [markdown]
# **Nejlepší výsledek, který se nám na Kagglu povedlo dosáhnout, 0.82122, byl získán z našeho finálního modelu, ovšem při použití 265té iterace (index 264). Náš druhý nejlepší výsledek, 0.82177, jsme získali při použití 266té iterace. Až jako třetí nejlepší vyšla iterace, kterou model na základě early stoppingu označnil jako best iteration (263. iterace, index 262  - technicky vzato 262. iterace, po ní už se model na validu nezlepšil, ale na testu ještě ano).**
